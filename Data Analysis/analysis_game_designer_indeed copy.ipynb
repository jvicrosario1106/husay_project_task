# %%
import matplotlib.pyplot as plt
import pandas as pd
from ast import literal_eval
import re

# %%
merge = pd.concat(map(pd.read_csv, ["../Raw_CSV/April 25-26 - 2022/Indeed/Indeed-game designer.csv","../Raw_CSV/April 27 - 2022/Indeed/Indeed-game designer.csv", "../Raw_CSV/April 28 - 2022/Indeed/Indeed-game-designer.csv","../Raw_CSV/April 21-22 - 2022/Indeed/game-designer.csv"]),ignore_index=True)

# %%
#Describing the data
merge.describe()
# Out:
#                      Title                                   Company  \
# count                  307                                       307
# unique                 106                                        73
# top     Lead Game Designer  Aruze Global Shared Services Philippines
# freq                    29                                        22
#
#        SalaryOne SalaryTwo          Location  \
# count        262       262               307
# unique        24        22                30
# top         None      None  Remote in Manila
# freq         230       212                43
#
#                                                   Summary Qualification  \
# count                                                 304           262
# unique                                                104           119
# top     Work with artists and programmers to ensure pr...            []
# freq                                                   16            39
#
#        Role&Responsibilities
# count                    262
# unique                   111
# top                       []
# freq                      52

# %%
#View Data's
merge
# Out:
#                                                  Title  \
# 0    new2D Game Artist/Designer (apply with portfolio)
# 1    Graphic Designer CAN START ASAP (Open for fres...
# 2                              Filipino Content Writer
# 3                         newGame Engineer - Homebased
# 4                                    newBrand Designer
# ..                                                 ...
# 302                                     Sr. Copywriter
# 303                                           Animator
# 304                                LEAD UX/UI DESIGNER
# 305                           newSenior Graphic Artist
# 306                         Email Marketing Specialist
#
#                                       Company SalaryOne  \
# 0                AIRCLASS (PHILIPPINES) CORP.      None
# 1                        J-K Network SERVICES      None
# 2                             Culture Flipper      None
# 3                              Altitude Games      None
# 4                                    Transbiz      None
# ..                                        ...       ...
# 302     TransBiz (eCommerce Marketing Agency)       NaN
# 303                                   Ubisoft       NaN
# 304                              Cebu Pacific       NaN
# 305  Aruze Global Shared Services Philippines       NaN
# 306                        Pilothouse Digital       NaN
#
#                            SalaryTwo               Location  \
# 0    PHP 30,000 - PHP 50,000 a month       Remote in Manila
# 1    PHP 25,000 - PHP 50,000 a month                 Makati
# 2                               None  Remote in Philippines
# 3                               None       Remote in Makati
# 4                               None                 Remote
# ..                               ...                    ...
# 302                              NaN       Remote in Makati
# 303                              NaN        Santa Rosa City
# 304                              NaN                  Pasay
# 305                              NaN      Makati+1 location
# 306                              NaN  Remote in Philippines
#
#                                                Summary  \
# 0    Familiar with interactive function logic, use ...
# 1    Create game logos, symbols, typography and des...
# 2    The team includes language experts, subject-ma...
# 3    Work with a team of artists, designers and oth...
# 4    We know that each member has a critical role t...
# ..                                                 ...
# 302  Being best buddies with the team designer and ...
# 303                Experience in video game animation.
# 304  Acts as a liaison to articulate feedback and d...
# 305  Works closely with other artists, game designe...
# 306  (copywriters, designers, landing page devs, Sh...
#
#                                          Qualification  \
# 0    ['Paid training', '8 hour shift', '13th month ...
# 1    ['HMO', '13th Month Pay', 'Government Mandated...
# 2    ['Write Filipino copy and text for advertiseme...
# 3    ['Work with a team of artists, designers and o...
# 4    ['\nAccess to training for your specialization...
# ..                                                 ...
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
#
#                                  Role&Responsibilities
# 0    ['Job description: ', "1. Familiar with intera...
# 1    ['URGENT HIRING ! Graphic Designer (CAN START ...
# 2    ['Culture Flipper is looking for a Filipino co...
# 3    ['Responsibilities: ', 'Requirements: ', 'Bonu...
# 4    ['WHO IS TRANSBIZ', '', '\nIf you consider you...
# ..                                                 ...
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
#
# [307 rows x 8 columns]

# %%
location = merge["Location"].value_counts()[0:10] # Location
salary = merge["SalaryOne"] + " " + merge["SalaryTwo"] # Salary
title = merge["Title"].value_counts()[0:10]

# %%
location.to_frame()
# Out:
#                        Location
# Remote in Manila             43
# Makati                       43
# Santa Rosa City              36
# Remote                       35
# Manila                       30
# Remote in Makati             21
# Pasig                        19
# Santo Tomas                  18
# Remote in Philippines         8
# Quezon City                   6

# %%
plt.bar(location.index, location.values,width=0.3)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
title.to_frame()
# Out:
#                                        Title
# Lead Game Designer                        29
# Game Designer                             17
# newGame Designer                          15
# Instructional Designer                    10
# Senior Product Designer (Remote)           6
# Graphic Designer (Illustrator)             6
# newSenior Amazon Designer (Creatives)      5
# Email Marketing Specialist                 4
# newSenior Graphic Artist                   4
# newCreative Director                       4

# %%
plt.bar(title.index, title.values,width=0.3,)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
company = merge["Company"].value_counts()[0:10]

# %%
company.to_frame()
# Out:
#                                            Company
# Aruze Global Shared Services Philippines        22
# Transbiz                                        21
# Ubisoft                                         19
# Onward Worldwide Management & Consultancy       18
# Assassin's Creed                                14
# Pixel Mafia                                     10
# Culture Flipper                                 10
# TransBiz (eCommerce Marketing Agency)            8
# Support Shepherd                                 7
# RetainLab                                        7

# %%
plt.bar(company.index, company.values)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
replace = merge["Qualification"].str.replace("^\['|'\]$","")
# Out:
# /var/folders/tc/qdg72rpx523gjsqcr2vf_0c00000gn/T/ipykernel_3591/1200321832.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   replace = merge["Qualification"].str.replace("^\['|'\]$","")

# %%
for i in range(len(merge["Qualification"])):
    a_list = literal_eval(merge["Qualification"][i])
    for j in range(len(a_list)):
        print(a_list[j])
# Out:
# Paid training
# 8 hour shift
# 13th month salary
# Performance bonus
# HMO
# 13th Month Pay
# Government Mandated Benefits
# Vacation Leave
# Performance Bonus
# At least a Bachelor’s Degree/College Degree, Art/Design/Creative Multimedia or any IT related course.
# Proficient in Microsoft Office applications and tools.
# Portfolio in Graphic design
# Create game logos, symbols, typography and design layout Conceptualizing visuals based o requirements.
# Prepare rough drafts and present ideas.
# Establish the look and feel for various interfaces, including mobile devices, slot machine, signages.
# Ensures that pre-production & print standards are accurate, correct and in line with the casino standards.
# Prepares mock-ups or prototype for approval.
# Completes project by coordinating with various teams of the company.
# Paid training
# 8 hour shift
# No
# Write Filipino copy and text for advertisements and communications
#
# Write easy-to-read press releases that improve upon translators' text and contextual explanations without changing the accuracy of the source material
#
# Write interesting and gripping synopses and reviews of books, movies and TV shows
#
# Perform other marketing-related tasks
# 3+ years' experience writing in public relations, marketing, or in publication
#
# Native Filipino speaking, writing and editing skills
#
# In-depth knowledge of Filipino grammar and usage, as well as a deep understanding of Filipino cultures.
#
# Ability to keep on task and meet firm deadlines
#
# Proficiency in an additional language preferred
#
# Understanding of the Korean language and culture is a plus
#
# Experience in the publishing industry including participation in international book fairs and literary festivals is a plus
#
# Interest and knowledge of popular culture, including industry trends pertaining to books, movies, TV shows, games, fine art and music
#
# Multitasking skills, flexibility, positive attitude as a team player and the ability to work with a multi-national team
# Work with a team of artists, designers and other engineers to release a mobile game
# Raise and/or solve technical issues when they arise
# Develop systems or tools that help speed up development
# Continuous learning to improve one's skills
# Computer science degree or equivalent
# Experience with Unity game engine using C#
# Experience with Git
# Knowledge of 3D graphics internals
# Strong math skills
# A team player
# Can work remotely with minimal supervision
# Excellent verbal and written communications skills, experience working with designers, artists and fellow programmers.
# Experience with Android and iOS development
# Has shipped titles under his/her belt
# Knowledge of other programming languages
# Company events
# Flextime
# Health insurance
# Pay raise
# Promotion to permanent employee
# Work from home
# 8 hour shift
# Day shift
# Flexible shift
# Monday to Friday
# Bachelor's (Required)
# Unity game engine: 1 year (Preferred)
#
# Access to training for your specialization and others within the agency, as well as a chance to attend courses to help you grow further.
# Fully remote and flexible working schedule that doesn’t restrict you to just one location, and you’ll be able to work when you feel the most productive and take a nap when you’re in need of a small boost of energy.
#
# Grow from a Sr. Digital Designer to, if wanted, the lead of the Digital Designer team to eventually having your own team to manage. Can’t have you getting bored!
#
# Conceive and build identity systems from the ground up, helping to create the visual elements for our clients;
#
# Work closely with team members to realize print, packaging, motion, and 3D executions;
# Assist senior teammates on design projects from brainstorming and initial concepting through final production;
# Have the ability to organize, prioritize, and manage multiple graphics projects at once. Use time effectively & efficiently;
# Clearly communicate questions and/or ideas to improve & develop the creative creation process;
# Follow creative creation processes and recommend advancements and/or tools where relevant;
# Take input, critique, and advice from team and client to move a project forward;
# Contribute to a positive, creative, and supportive atmosphere.
#
# You have 3 years of experience as a Graphic Designer for a Branding team.
# You have a portfolio of digital designs to showcase;
# You have previous experiences studying and/or working in Digital Marketing;
# You have in-depth experience with Photoshop, & Illustrator. Some experience with Adobe Premiere & After Effects would be a bonus;
# You are confident to present and defend your works.
# You are good at researching for inspiration and references.
# You are keen on details.
# You are flexible to work with different clients/industries.
# You are fluent in English (written and spoken).
# You are able to present works to clients in meetings.
# You must resonate with our Vivid Vision 2024.
# Work experience in eCommerce;
# Basic knowledge of web design layout;
# Can assist or handle photoshoots (we usually do virtual shoots).
# Create a wide range of graphics and layouts for product illustrations, company logos, and websites with software such as Photoshop, Illustrator, etc.
# Use the appropriate colors and layouts for each graphic
# Test graphics across various media
# Ensure final graphics and layouts are visually appealing and on-brand
# Reports to Team Lead and Digital Marketing Manager
# Complete tasks within the timeframe allotted for it
# Do daily updates with the team lead about task timeline
# Able to be creative while also conforming to set guidelines
# BS Degree in Design or related field; or relevant work experience
# Open for Fresh Graduates
# Demonstrable graphic design skills with a strong portfolio.
# Proficiency with required desktop publishing tools, including Photoshop, InDesign, and Illustrator.
# A strong eye for visual composition.
# Effective time management skills and the ability to meet deadlines.
# Able to give and receive constructive criticism.
# Understanding of marketing, production, website design, corporate identity, product packaging, advertisements, and multimedia design.
# Great company culture
# Competitive salary
# Equipment Budget
# Leave Credits & HMO after probation
# Huge growth opportunities
# Employee Engagement Activities (virtual gathering, game night, anniversary & Christmas tokens, etc.)
# Open Door Policy
# Flextime
# Work from home
# 8 hour shift
# 13th month salary
# Please send a link to your design portfolio
# Graphic Design: 1 year (Required)
# You will be creating 3D models from architectural plans, rough sketches or real – life objects using special rendering software.
# You will apply textures and providing appropriate lighting techniques to the models.
# You will work with designers to understand the design intent to create 3D visuals for a range of interior projects.
# You will work on production of quality imagery including post-production work.
# You will ensure the provision of the highest possible quality information, within the pre-determined time frame for each assignment.
# You will perform any additional responsibilities as may be requested or assigned from time to time.
# You are an 3D visualizer with a minimum of 5 - 8 years of relevant experience of interior projects.
# You have advanced knowledge of 3D-StudioMax, V-Ray and Adobe Creative Suite.
# You should be able to produce results in a fast paced environment.
# You have experience in the production of quality imagery including lighting, texturing and post-production work
# You should have good understanding of technical drawings for Interior Design.
# You are a team player with a positive attitude to go the extra mile
# You will subscribe to the company core values of Teamwork, Integrity and Excellence.
# Health insurance
# 8 hour shift
# Has in-depth Knowledge of Adobe PhotoShop, Illustrator, PainTool SAI, or other graphic design software
# Must love to watch Anime and reads manga
# Updated with the latest anime trends and news
# Must know the latest meme trends
# Must have knowledge online games
# Creative enough to brainstorm new designs
# Team player, Proactive and willing to go extra mile to produce quality results
# Strong Interest and Passion for Anime Niche is a must.
# WFH (100% Remote work)
# Salary payment via WISE
# Annual Bonuses
# Annual Healthcare Benefits
# Annual Software/Hardware Upgrade Benefits
# Annual Paid Leaves
# A cool and fun working environment
# Cool and trendy merch prizes
# Reliable Internet Connection with at least 50 MBPS, with back-up provider
# For Windows users:
# For MAC users:
# Create digital experiences that achieve objectives and solves challenges creatively.
# Design, layout and code modern, functional, websites, apps, games and other interactive digital experiences.
# Create digital marketing collaterals. (emails, web banners, landing pages, etc.)
# Maintain and update existing digital properties.
# Collaborate with other teams within the company to pioneer innovative interactions.
# Candidate must possess at least a Bachelor's/College Degree, Computer Science, Fine Arts, Multimedia or equivalent course.
# Expert in using Adobe Creative Suite products, most importantly Photoshop, Illustrator and Flash.
# Updated in contemporary user interface and experiences
# Experience with HTML/CSS. (JavaScript, jQuery a plus)
# Solid visual and interaction design sense.
# Strong sense of initiative and ability to work under pressure on multiple projects.
# Independent thinker, team player.
# Applicants must be willing to work in Makati City.
# Fresh graduates are welcome to apply.
# Portfolio is a MUST.
# Candidate must possess at least a Bachelor's/College Degree , any field.
# At least 1 year(s) of working experience in the related field is required for this position.
# Preferably 1-4 Yrs Experienced Employees specializing in IT/Computer - Network/System/Database Admin or equivalent.
# Full-Time position(s) available.
# Enhance product functionality
# Maintain quality
# Achieve Company Target
# Computer Hardward/ Software Troubleshooting
# With experience on the following:
# Sketch
# Invision studio
# Axure
# Craft
# Photo.io
# Adobe XD
# Marvel
# Figma
# Framer X
# Webflow
# Create enhancement logic useful to users and product (Target increase active player, transaction & Playtime)
# Competitor Survey & Report
# Coordinate with Internal & external to solve any product matters
# Maintain Product Quality (UAT)
# Report Documentation via axure software
# 10 hour shift
#
# You have deep expertise in Instructional design and delivery, with a focus on learner centric design.
#
# You have extensive project management skills and experience delivering large or complex projects involving multiple collaborators and moving parts.
#
# You have a passion for execution and seeing projects through end to end.
#
# You have experience establishing relationships with partners quickly to deliver a flawless end product.
#
# You have stakeholder engagement and leadership skills and ability to keep everyone on track and accountable.
#
# You bring strong facilitation and group coaching skills.
#
# You have strong attention to detail.
#
# Establish relationships with our Specialty partners (specialty lead, SMEs, coaches) in order to elicit and develop learning content
#
# .Work with our specialties consists of a diverse range of subject matter experts and stakeholders to capture and craft instructional content specialty curriculum.
#
# Act as a thought partner to help Specialty SMEs and bring their content and expertise to life
#
# Work closely with the rest of the People triad (Talent Acquisition Partner and HR Business Partner) to operationalize the tailored people plan for the specialty.
#
# Use your instructional design background to craft compelling learning content, experiences and materials using a variety of tools - predominantly the Canva app, video and e-learning tools.
#
# Digitise and transform our existing specialty learning content into highly engaging, bite sized learning experiences, blended learning and playbooks.
#
# Blend existing and new learning content into pathways and curriculums.
#
# Analyse Instructor/course performance trends and translate these findings into actions to meet both learning and business goalsFacilitate instructor led sessions when required both in person and webinar formats.
#
# Identify, track and analyse key course and learner metrics, and provide recommendations to constantly improve the experience.
#
# Handle multiple projects with differing deadlines, keeping others on track and informed, and ensuring goals are clear and met on time.
#
# Upskill our internal facilitators and coaches where necessary.
#
# Communicate complex ideas visually. Canva University aims to make the complex simple, taking big broad topics and making them applicable, engaging and accessible to everyone. This person will take complex concepts and communicate it simply, visually, and across various mediums.
#
# Effective at leading multiple projects. As this person will juggle multiple projects and help chart new territory in building out our course structure and designing new learning content, they will be adept at running their own time and priorities, to get things done well and on time.
#
# Adaptive to change. We work iteratively and adaptively, and with that comes a lot of trial and error and moving pieces as we settle works best for our learners. This person should be comfortable with a level of ambiguity.
#
# Communicate effectively with various stakeholders. This person will need to communicate clearly and work with internal and external parties to create the best online and in person courses.
#
# Design and Digital Savvy. Internally, Canva has a high bar for visual communication - we love to show, not just tell. We're here to help support Canvanauts with upping their visual communication game. We want Canvanauts to be able to communicate their ideas across the business, landing with impact. This person will be design and digitally savvy, constantly working in the Canva app, with video, e-learning and other digital modalities to design new and visually compelling learning experiences. We’re looking for someone who can not only design amazing learning content, but can translate this across a range of digital mediums too!
#
# Learn new skills and adapt to what the role needs. This person will need to be open to learning new skills, whether that’s basic animation, screen flow tutorials or instructional design. (Whatever the job requires!)
# A temporary work from home setup as we prepare to provide a safe environment for Canvanauts who would like to work in the office. Our Future of Work plan is to move towards a hybrid work model (in-office & from home) which brings our people together for 8 key days a year. The rest of the year, you and your team can determine your ideal work setup. Whichever works best for you, #KayaSaCanva.
# Unique and flexible leaves options: :Recharge and go on your next getaway or simply take time off for yourself through our Vacation Leave, Give back through our Volunteer Leave to help out a charity or NGO of choiceSupport yourself or take care of your loved ones (even your furbabies) through our Sick or Carer’s Leave
# Focus on your own growth and development through our Professional Educational Leave
# An annual Vibe & Thrive allowances for you to spend on anything that supports your wellbeing. Whether it’s a workshop, an electronic stand-up desk, a gym membership, or dinner with a teammate, we encourage you to do what you need to do in order to thrive.
# Virtual and in-office wellness and development benefits including Canva University, Employee Assistance Programs, Fitness Classes and more to support your physical, mental, and social wellbeing.
# Canva For Good program that matches your not-for-profit donations and a range of sustainability and ethical initiatives to get involved in.
# A variety of Canva clubs that you can join to connect you to fellow Canvanauts with similar interests. From cycling, skincare, pets, to foodies (and the list goes on), we got you covered! Club activities can also be done remotely or in person.
#
# Access to training for your specialization and others within the agency, as well as a chance to attend courses to help you grow further.
# Remote work set-up. You’ll be able to work when you feel the most productive and take a nap when you’re in need of a small boost of energy.
# Be the pioneer member of the team and gain the experience of building and growing it from the ground up.
#
# Creating effective materials and design for social media, to be posted on platforms like Facebook, Instagram, and Amazon.
# Conceptualizing and executing profit-converting e-mail marketing designs for brands.
# Building original illustrations or doing image manipulation.
# Proposing of eye-catching inserts for long-form blog posts or creating infographics optimized for digital consumption.
# Having basic knowledge and skills in video editing. While the role primarily involves static images and gifs, basic video editing may also be required every now and then.
#
# You will have 1-3 years of experience in Design, preferably in doing Digital work.
# You will provide a portfolio of your digital designs.
# You may be comfortable with dynamic deadlines.
# You should be results-driven with an open mind for improvement.
# You are detail-oriented, self-driven, and collaborative.
# You are fluent in English.
# You are able to work in a fast-paced environment.
# You have skills in mobile photography, video, and experience with GIFs.
# You will resonate with our Vivid Vision 2024.
# Review and understand internal and clients’ creative briefs.
# Create creative and modern designs for mobile games and applications.
# Communicate with the department for design pitch and modification.
# Work with a team of designers and developers.
# Research the latest trends in web designs and graphic arts.
# Ability to work under pressure and tight schedules and deadlines.
# Proven graphic designing experience for at least 1 year
# Must be savvy in Adobe Illustrator.
# Knowledge in Adobe Photoshop, After Effects, 3D Software and Adobe Creative suite is an advantage
# Possession of creative flair, versatility, conceptual/visual ability and originality
# Demonstrable graphic design skills with a strong portfolio
# Ability to interact, communicate and present ideas
# Highly proficient in all design aspects
# Professionalism regarding time, costs and deadlines
# Amenable to work in Ayala, Makati once pandemic is over.
# Can start as soon as possible
#
# Access to training for your specialization and others within the agency, as well as a chance to attend courses to help you grow further.
# Fully remote and flexible working schedule that doesn’t restrict you to just one location, and you’ll be able to work when you feel the most productive and take a nap when you’re in need of a small boost of energy.
# Grow from a Senior Amazon Designer to an Art Director role. A career path will be built with you to create KPIs so you can measure your own growth and success to the next step. Be a creative Senior Digital Designer who has that drive to make a difference.
# Turning the client’s vision into reality by using their brand bible, tone of voice, target audience, and style scape;
#  Designing amazon and Shopify product listing images that will make customers stop and say, “yep. I need this product in my life.”;
#  Being the art director’s right hand and staying on top of all the design projects;
#  Being best buddies with the team copywriter and plan concepts together by studying the kick-off brief and doing a deep dive research;
#  Knowing exactly what you need even before opening photoshop and getting them directly from the client;
#  Taking criticism positively because you know well that not everyone will be a fan of your design and that the client may have a different vision in mind;
#  Confidently presenting your ideas and work to the team and the client because you are an expert in digital design and marketing;
#  Making time for training. We have tons, and we mean a lot of training materials available in our database – from design to personal development. Every day is a chance to learn, or revisit something;
#  Guiding and reviewing the Junior Designer’s work and helping him/her grow.
# Staying on top of the latest digital marketing and design trends and helping optimize the team’s SOPs.
#
# You must be a visual marketer. Your mind should be filled to the brim with creative ideas and practices and apply that imagination to every part of your work;
# You wow, us with your expansive portfolio featuring all your digital designs;
# You know the ins and outs of photoshop and illustrator. Experience with adobe premiere and After Effects would be a bonus;
# You are finicky. You want lines straight and edges clean. Quality is a top priority;
# You are consistent, whether it’s in using the brand’s color scheme in your designs or how you work in general;
# You're always up for the challenge and ready to solve problems. We don’t expect you to save us all, but your willingness to help will make a difference;
# You practice patience. Not every project will be smooth-sailing, and the best ideas don’t come quickly. It takes a lot of collaboration between the team and the client. But you know that the outcome is more important than going back to the drawing board multiple times. That’s also why we need you to;
# You prioritize results. At the end of the day, your design serves a purpose. It should catch the eye of the target customer, keep them going through your work, and eventually lead them to click that BUY NOW button.
#
# You resonate with our Vivid Vision 2024.
# Day shift
# Please send resume and portfolio
# remote team: 2 years (Preferred)
# Analyse, design and develop AUG website with IT & Communications Team.
# Design and develop graphic design, digital animations, imaging, presentations, games, audio and video clips, and internet applications using multimedia software, interactive graphics and programming languages.
# Design, develop and integrate computer code with other specialised inputs, such as image files, audio files and scripting languages, to produce, maintain and support websites
# Create and manipulate computer animation, audio, video and graphic image files into multimedia programs to produce data and content for multimedia presentations, websites and social media contents
# Ensure designs and creative are on time and on brief, bringing brand and customer experiences to life through motion, animation and visual storytelling.
# Design all AUG's advertisement, signage, printed stationeries, premium and promotional materials.
# Edit institution advertisement before publication.
# Maintain communication with Australia's Communication team for consistency in all projects.
# Source for new media ideas.
# Update offices of AUG's advertisement, new printed stationeries, premium and promotional material.
# Place orders for advertisement and signage.
# Advertisement design (Print & Web).
# Design and layout of publications.
# Online marketing events and promotions.
# Design promotional and marketing materials such as brochures, poster flyers etc.
# Work closely with Communications & Marketing team in various offices
# Excellent communication and interpersonal skills
# Can adapt to change and last-minute deadlines easily
# Ability to come up with quick design and understand the latest trends
# Passion for events and the education industry
# High attention to detail and a strong work ethic combined with the ability to work independently and with others
# Additional leave
# Health insurance
# Life insurance
# On-site parking
# Opportunities for promotion
# 8 hour shift
# 13th month salary
# Performance bonus
# San Juan: Reliably commute or planning to relocate before starting work (Required)
# Ensure the design and the graphics production of the game’s UI / UX
# Develop concepts and design eye pleasing but functional game UI
# Work closely with the art director, engineers and game designers to produce functional UI
# English is your working language.
# Top-notch communication, collaboration, and problem-solving skills
# Work efficiently under pressure and within deadlines
# Strong leadership and project management skills
# Able to work with a cross-functional team, engineering team & UI/UX designers
# Have been using Discord for a while
# Enjoy mobile gacha games and MMORPGs
# Strong portfolio of your Games Design with RPG
# MUST have prior experience in digital illustrations, anime illustrations, game or entertainment
# 5-10+YOE in UI design experience in the gaming industry
# Intensive experience in Photoshop, Figma, Illustrator
#
# Creative and artistic nature and vision
# Making design pixel perfect and up to web/mobile standards
#
# Access to training for your specialization and others within the agency, as well as a chance to attend courses to help you grow further.
# Fully remote and flexible working schedule that doesn’t restrict you to just one location, and you’ll be able to work when you feel the most productive and take a nap when you’re in need of a small boost of energy.
# Grow from a Senior Amazon Designer to an Art Director role. A career path will be built with you to create KPIs so you can measure your own growth and success to the next step. Be a creative Senior Digital Designer who has that drive to make a difference.
# Turning the client’s vision into reality by using their brand bible, tone of voice, target audience, and style scape;
#  Designing amazon and Shopify product listing images that will make customers stop and say, “yep. I need this product in my life.”;
#  Being the art director’s right hand and staying on top of all the design projects;
#  Being best buddies with the team copywriter and plan concepts together by studying the kick-off brief and doing a deep dive research;
#  Knowing exactly what you need even before opening photoshop and getting them directly from the client;
#  Taking criticism positively because you know well that not everyone will be a fan of your design and that the client may have a different vision in mind;
#  Confidently presenting your ideas and work to the team and the client because you are an expert in digital design and marketing;
#  Making time for training. We have tons, and we mean a lot of training materials available in our database – from design to personal development. Every day is a chance to learn, or revisit something;
#  Guiding and reviewing the Junior Designer’s work and helping him/her grow.
# Staying on top of the latest digital marketing and design trends and helping optimize the team’s SOPs.
#
# You must be a visual marketer. Your mind should be filled to the brim with creative ideas and practices and apply that imagination to every part of your work;
# You wow, us with your expansive portfolio featuring all your digital designs;
# You know the ins and outs of photoshop and illustrator. Experience with adobe premiere and After Effects would be a bonus;
# You are finicky. You want lines straight and edges clean. Quality is a top priority;
# You are consistent, whether it’s in using the brand’s color scheme in your designs or how you work in general;
# You're always up for the challenge and ready to solve problems. We don’t expect you to save us all, but your willingness to help will make a difference;
# You practice patience. Not every project will be smooth-sailing, and the best ideas don’t come quickly. It takes a lot of collaboration between the team and the client. But you know that the outcome is more important than going back to the drawing board multiple times. That’s also why we need you to;
# You prioritize results. At the end of the day, your design serves a purpose. It should catch the eye of the target customer, keep them going through your work, and eventually lead them to click that BUY NOW button.
#
# You resonate with our Vivid Vision 2024.
#
# Using our authoring tool, you will be given briefs from our Instructional Designers and Account Managers to create training courses and micro-lessons, either for clients or for our growing course library.
#
# You will be researching and writing the course content, but also using image editing and visual design tools to enhance the look and feel of the micro-lessons.
#
# You will review materials and documents to structure and produce courses, as well as sourcing other relevant information and assets.
#
# You may from time to time jump on a zoom call with a client to get a live brief for their specific training materials.
#
# You may from time to time need to jump on a zoom call with a client directly to walk them through your lesson and design, explaining the use of templates and showing them how they can further edit their courses if they’d like.
#
#
# You will build strong and collaborative relationships with our team of Instructional Designers and Account Managers who are located across Sydney, New York and London.
#
# You will actively contribute to the Manila office culture.
#
# You love to research.
#
# You will be given briefs on a range of topics and industries so you will need to have the desire to become the subject matter expert quickly
#
# You have a strong, goal-oriented work ethic and are proactive in your approach to tasks.
#
# You are eager to learn and grow. You have an instructional mindset and can grasp the concept of learning objectives
#
# You have strong written and verbal communication skills and are able to have conversations with clients directly regarding design briefs
#
# You thrive work independently in a dynamic and in a fast-paced environment
#
# You are a great planner with great attention to detail
#
# Minimum 1-2 years of work experience - ideally in Learning & Development, Design, Customer Support or a teaching discipline.
#
# An interest or passion for teaching and education
#
# Preferably used design and editing tools such as Adobe Creative Cloud, Photoshop, In-Design, or Canva and are comfortable with visual design.
#
# Been in a customer facing role where you have had the experience of conducting training or technical support.
#
# Basic HTML or CSS skills would be a big plus!
#
# Used Slack and Trello for communication and project management.
#
# Company Christmas gift
# Company events
# Free parking
# Health insurance
# Life insurance
# On-site parking
# Paid training
# Promotion to permanent employee
# Transportation service provided
# 8 hour shift
# Day shift
# 13th month salary
# Overtime pay
#
# Access to training for your specialization and others within the agency, as well as a chance to attend courses to help you grow further.
# Fully remote and flexible working schedule that doesn’t restrict you to just one location, and you’ll be able to work when you feel the most productive and take a nap when you’re in need of a small boost of energy.
# Grow from a Brand Strategist to a Brand Manager, with a small team of your own. A career path will be built with you to create KPIs so you can measure your own growth and success to the next step.
#
# You will help clients in researching, conceptualizing, and writing strategies for the brand that the team is creating.
# You will attend client meetings/presentations. Prepare questions and head client discovery calls.
# You will also have some brainstorming sessions with the team to help further develop the ideas for brands.
# You will clearly brief the branding designer.
# You will create decks and confidently present works to clients.
# You will conduct market research and analyze data to map out the competitive landscape and find customer insights.
# You will create a customer avatar.
# You will develop brand positioning and messaging.
#
# You will write the brand story.
# You will come up with awesome brand names and taglines.
# You will plan the unboxing experience.
# You will write copies for packaging and inserts/manuals.
#
# You will ensure consistent messaging throughout all deliverables/materials.
#
# You have experience working in fast-paced marketing/branding projects.
# You have a basic understanding of the full marketing mix.
# You have good communication and copy-writing skills.
# You have strong research skills and have a problem-solving mindset.
# You are creative, committed to being open-minded, and thinking outside of the box.
# You are well versed in leading client meetings.
# You have a strong interest in branding and strategy.
# You have the appetite for learning and the thirst to grow as a brand strategist.
#
# You resonate with our Vivid Vision 2024.
# Work from home
# 8 hour shift
# Bonus pay
# Commission pay
# Overtime pay
# Performance bonus
# 8 hour shift
# Commission pay
# Yes
# Health insurance
# Pay raise
# Promotion to permanent employee
# 8 hour shift
# Monday to Friday
# 13th month salary
# Performance bonus
# Access to training for your specialization and others within the agency, as well as a chance to attend courses to help you grow further.
# Fully remote and flexible working schedule that doesn’t restrict you to just one location, and you’ll be able to work when you feel the most productive and take a nap when you’re in need of a small boost of energy.
#
# Grow from a Creative Director to, if wanted, be one of the leads of the Branding and Creatives team to eventually having your own team to manage. Can’t have you getting stuck with where you are!
# Handling QA for all designs, videos, sites and will be the last in line for approval
# Committing to be up to date in each brand's tone of voice and looks and ensures that the team members use them on all design materials for consistency and cohesiveness
# Creating designs and ads to deliver outstanding quality
# Overseeing and mentoring designers to provide guidance in creating better quality materials
# Researching potential workshops and training that would help the team member's career growth
# Proactively be the "go-to" person in terms of design, creative part of digital marketing, market trends and responsible for sharing the knowledge with team
# Providing constructive criticism to team members as a way of practicing transparency
# Genuinely caring for the brands and propose ways for improvement
# You have prior experience in working & coordinating well with a team of creatives as an art director/creative director in the past.
# You're up to date with the latest trends in ads, UI design, have insights into customer behavior, & have deep knowledge in digital marketing.
# You're capable of taking over design works such as social media, ad images, etc. if needed
# You already have experience being in a leadership position with knowledge in management & are more comfortable presenting ideas to the clients and team members
# You have a background in working in an advertising agency or a digital marketing firm.
# You’re a great verbal and written communicator
# Already have a portfolio displaying the techniques & skills we are looking for.
# You must resonate with our Vivid Vision 2024.
# Work with Filipino writers to ensure that content is optimized for target keywords in Filipino
#
# Recommend Filipino keywords and categorize keyword research and search topics into related groups for client implementation on social media platforms
#
# Stay up to date on best practices for universal, non-Google keyword research
#
# Ensure that English and Filipino SEO processes align
# 2+ years of experience in technical or content SEO, SMO or any related digital marketing fields
#
# Ability to perform keyword research manually
#
# Absolutely fluent Filipino speaking and writing skills
#
# Ability to keep on task and meet firm deadlines
#
# Must be good at multitasking, be flexible and a positive team player
#
# Able to work with a multi-national team
# Understanding of Filipino culture a huge plus
#
# Additional language proficiency a plus
#
# Any digital marketing certifications (i.e. Google) a huge plus
# Cultivate a solid body of work
#
# Take the design “brief” to record requirements and clients/PD/Marketing managers’ needs
#
# Schedule project implementation and define budget constraints
#
# Work with a wide range of media and use graphic design software
#
# Think creatively and develop new design concepts, graphics and layouts
#
# Prepare rough draft and present your ideas
#
# Amend final designs to clients/Product Development/Marketing managers’ comments and gain
#
# Work as part of a team with product development, marketing and operation’s team members
#
# Required to live in Manila, Philippines
#
# Required language(s): English and Chinese (Mandarin) both in written and oral
#
# Proven graphic and/or web designing experience
#
# Strong background with digital imaging correction/touch up
#
# Movie / game poster design background
#
# Possession of creative flair, versatility, conceptual/visual ability and originality
#
# Demonstrable graphic design skills with strong portfolio
#
# Ability to interact, communicate and present ideas
#
# Up-to-date with industry leading software and technologies
#
# Experience in graphical user interface
#
# Minimum 3 years’ experience as a graphic designer in related industry
#
# Experienced in phone apps design is a plus
#
# Attached Phone APPs/PDF/Picture/link of candidate’s portfolio for our perusal
# Communicate with and assist customers from around the world, answering questions regarding our services via the web support chat (Intercom)
# Provide excellent customer support by identifying customer needs and dealing with tasks independently
# Ensure that conversations are managed and prioritized in an orderly manner
# Prioritize incoming cases and escalating them further if it is required
# Experience in IT product or service remote support (1st or 2nd line)
# Solid technical knowledge relevant to SaaS or software specifics and infrastructure, such as API, CLI, application configuration, data integration
# Ability to explain complicated matters using simple words
# Outstanding emotional intelligence – you know how to actively listen, you can easily communicate with people, convey ideas clearly, and establish quality relationships with others
# Fluent written English skills
# Located in South Korea, Singapore, Philippines or Indonesia
# A critical thinker with good troubleshooting skills
# A positive, self-starter with a resilient attitude
# A team player
#
#
#
# Previous experience in the localization industry
# Previous experience providing live chat support
# Competitive salary and employee stock options plan
# Learning & Development program
# Flexible working hours
# Unlimited vacation policy
# Health insurance
# Wellness benefits
# Comprehensive parental leave
# Coworking budget
# Top-notch tech equipment to work with
# Great startup atmosphere, team spirit, and team events
# Create engaging learning activities and compelling course content that enhances retention and transfer
# Work with subject matter experts, reference materials and identify target audience’s training needs
# State instructional end goals and create content that matches them
# Visualize instructional graphics, the user interface and the finished product
# Conduct instructional research and analysis on learners and contexts
# Apply tested instructional design theories, practice and methods
# Provide exercises and activities that enhance the learning process
# Create supporting material/media (audio, video, simulations, role plays, games etc)
# Decide on the criteria used to judge learner’s performance and develop assessment instruments
# Maintain project documentation and course folders
# Proven working experience in instructional design and with instructional technology
# Excellent knowledge of learning theories and instructional design models
# Lesson and curriculum planning skills
#
# Solid knowledge of course development software and at least one Learning Management System (E.g., TalentLMS)
# Visual design skills (Dreamweaver, Photoshop, Illustrator) and ability to storyboard
# Ability to write effective copy, instructional text, audio scripts/video scripts
# BS or MA degree in instructional design, educational technology or similar
# Cryptocurrency-related market research planning
#
# Quantitative investigation and analysis
#
# Conduct and analyze qualitative research
#
# Trend analysis and reporting
#
# Help facilitate and grow the research group using your industry network in your country
# Proven minimum 5 years experience as a market researcher
#
# Knowledge in the cryptocurrency industry best practices and standards
#
# Excellent communication skills both in English and your native language
#
# Problem-solving aptitude
#
# Ability to work well with a team
#
# Master's Degree or higher education in marketing, t business, survey methodology or a related field preferred
# Reviews initial training requirements and documentation from Subject Matter Experts (SMEs)
# Works with stakeholders and SMEs to understand needs, make recommendations, and develop training to continuously improve employee performance
# Manages all aspects of training projects through the learning design process
# Regularly communicates project status to stakeholders and SMEs
# Designs and develops innovative and impactful training solutions that address learner needs and deliver measurable results to the business
# Enhances and maintains existing learning programs
# Creates and implements learning materials consistent with adult learning principles
# Employs effective instructional design strategies to maximize learning and engagement
# Creates supporting training materials/media (audio, video, simulations, role-plays, games, etc.)
# Effectively use training technology tools and software (e.g, Articulate, Captivate, Vyond, Camtasia, G Suite, etc.)
# Conducts train the trainer sessions on how to deliver training materials
# Ensures training solutions both meet the identified need for instruction and are effective in achieving the intended learning outcomes
# Executes learning evaluation strategies based on Kirkpatrick's levels of evaluation
# Summarizes training results/business impacts and shares with key stakeholders
# Maintains project documentation and course folders
# Expresses ideas in a clear and constructive, and professional manner
# Ensures that training materials are properly reviewed and approved by key stakeholders
# Demonstrates flexibility, adaptability, and is open to giving/receiving constructive feedback
# Appropriately follows team procedures and processes
# Manages responsibilities and priorities in a fast-paced and time-critical environment
# At least three (3) years in the Instructional Design field and a minimum of three (3) years in the Training field
# Has excellent verbal and written communication skills
# Has excellent presentation and facilitation skills
# Has strong organizational and time management skills
# Has a strong sense of accountability
# Skilled in building professional relationships with internal and external clients
# Background in training/teaching and/or adult learning preferred
# Project Management experience is a plus
# Knowledge in Adobe Photoshop, Premiere, Flash, HTML principles is a plus
# Temporary Work From Home set-up
#
# Joining catch-up calls with designer on priorities
#
# Preparing research proposal for Methods Lab
#
# Presenting insights for product and sync with designers on what’s next
#
# Engaging product managers and business stakeholders to raise awareness of issues that users face and recommend better solutions
#
# Ending the day by sharing and playing games on Friday team meeting
#
# Define, plan, and conduct independent research on multiple aspects of products and experiences to drive actionable changes in airasia’s growth strategy
#
# Collect and analyse user behaviour using various research methods such as field studies, surveys, usability testing, benchmark studies, tracking, metrics, and online experiments
#
# Work with Designers, Product Managers, Software Engineers, and other UX Researchers to prioritise research opportunities in a fast-paced and rapidly changing environment
#
# Understand and incorporate complex technical and business requirements into research
#
# Advocate research findings to diverse audiences through written reports or creation of research artefacts
#
# Create and design a good-quality presentation to describe a study and the results in simple words (words of the users without losing the essence). Independently present the results of the study to the team and stakeholders
#
# Provide feasible solutions or tips to solve operational problems and coordinate resources of business/operations teams to advance the implementation of research results and follow up on the results
#
# Master the user research knowledge and assimilate it within airasia and guide the professional growth of team members
#
# Experience conducting user interviews, field visits, and usability studies either live or remote (e.g., Userzoom or UserTesting.com)
#
# Experience integrating user research into product designs and design practices
#
# Ability to judge research feasibility to solve the product’s core experience problem
#
# Strong understanding of the strengths and shortcomings of different research methods including when and how to apply them during the product development process
#
# Effective interpersonal, communication, negotiation, and collaboration skills
#
# Prior experiences working alongside product team is preferred
#
# A Bachelor’s Degree in a related field is preferred
# Health insurance
# Life insurance
# Opportunities for promotion
# Paid training
# Staff meals provided
# 8 hour shift
# Early shift
# Monday to Friday
# 13th month salary
# Overtime pay
# Santa Rosa City, Laguna: Reliably commute or planning to relocate before starting work (Required)
# 8 hour shift
# Makati City: Reliably commute or planning to relocate before starting work (Required)
# Flexible schedule
# Health insurance
# Life insurance
# Paid training
# Pay raise
# Work from home
# 8 hour shift
# 13th month salary
# Overtime pay
# Bachelor's (Preferred)
# Conceptualize and craft campaigns and activities that achieve business objectives.
# Create layouts, designs and motion content (videos, GIFs etc) assets for use in social media plans, on ground activations and above the line channels.
# Be involved with in house productions (shoots, production design, food styling etc).
# Collaborate with other teams within the company to create innovative and pioneering content.
# Candidate must possess at least a Bachelor's/College Degree, Fine Arts, Multimedia or equivalent course.
# Expert in using Adobe Creative Suite products, most importantly Photoshop, Illustrator and Flash.
# Updated in fresh and exciting design, layout and motion content trends.
# Solid visual and storytelling sense.
# Strong sense of initiative and ability to work under pressure on multiple projects.
# Independent thinker, team player.
# Applicants must be willing to work in Makati City.
# Fresh graduates are welcome to apply.
# Portfolio is a MUST.
#
# Create quality 2D assets which conform to the project’s visual style
# Proactively work with other artists, designers and programmers to meet design challenges
# Can easily adjust with different 2D tasks
# Work in a fast paced and dynamic environment
# Collaborate productively with others and work hard to meet deadlines as necessary
#
# Excellent grip of Adobe Photoshop and related Graphic software
# A solid background on both traditional and digital drawing and illustration with flexible art style
# Think creatively, work well independently and a team player
# Has played a variety of games on different genre and platforms
# Excellent communication and interpersonal skills
# Ability and willingness to accept and follow direction
# Previous experience in doing art for games or working in a game studio is an edge
# Candidates without a portfolio WILL NOT be considered.
#
#
# Resume
# Online Portfolio
# Company Christmas gift
# Company events
# Health insurance
# Life insurance
# Paid training
# Promotion to permanent employee
# 8 hour shift
# Day shift
# 13th month salary
# Review and understand internal and clients’ creative briefs.
# Create creative and modern designs for mobile games and applications.
# Communicate with the department for design pitch and modification.
# Work with a team of designers and developers.
# Research the latest trends in web designs and graphic arts.
# Ability to work under pressure and tight schedules and deadlines.
# Proven graphic designing experience for at least 1 year
# Must be savvy in Adobe Illustrator.
# Knowledge in Adobe Photoshop, After Effects, 3D Software and Adobe Creative suite is an advantage
# Possession of creative flair, versatility, conceptual/visual ability and originality
# Demonstrable graphic design skills with a strong portfolio
# Ability to interact, communicate and present ideas
# Highly proficient in all design aspects
# Professionalism regarding time, costs and deadlines
# Amenable to work in Ayala, Makati once pandemic is over.
# ...
# 8 hour shift
# Day shift
# 13th month salary
# Overtime pay
# Understand consumer needs and ensure that the elements developed by the team will contribute to player satisfaction and enjoyment
# Work with project managers to determine and assess project scope, production capacity and set priorities for the team
# Work with artists and programmers to ensure proper implementation of the game features designed
# Delegate tasks and track the progress of the team’s deliverables
# Communicate project objectives and strategies to team members
# Provide clear and structured project documents to ensure that gameplay intentions are understood
# Actively participate in the decision-making process with management and oversee the necessary adjustments to ensure that the team meets expectations
# Create a work environment that is motivating for team members and which fosters development and creation
# Support career advancement and suggest development and interpersonal skills training and techniques sessions to team members
# Carry out performance follow ups and assessments
# Participate in the selection of team members
# Any other ad-hoc duties, if necessary
#
# Must have shipped at least 2 AAA games as a Lead or Senior Game Designer role
# Has experience in leading a multidisciplinary team
# Excellent communication and interpersonal skills
# Strong management and planning skills
# Highly organized and analytical
# Excellent management and planning skills
# Proactive and enthusiastic team player
# Solution oriented and ability to work effectively under pressure
# Passionate about playing and creating games
# Candidate must possess at least a Bachelor's/College Degree , any field.
# At least 1 year(s) of working experience in the related field is required for this position.
# Preferably 1-4 Yrs Experienced Employees specializing in IT/Computer - Network/System/Database Admin or equivalent.
# Full-Time position(s) available.
# Enhance product functionality
# Maintain quality
# Achieve Company Target
# Computer Hardward/ Software Troubleshooting
# With experience on the following:
# Sketch
# Invision studio
# Axure
# Craft
# Photo.io
# Adobe XD
# Marvel
# Figma
# Framer X
# Webflow
# Create enhancement logic useful to users and product (Target increase active player, transaction & Playtime)
# Competitor Survey & Report
# Coordinate with Internal & external to solve any product matters
# Maintain Product Quality (UAT)
# Report Documentation via axure software
# 10 hour shift
# Company Christmas gift
# Company events
# Free parking
# Health insurance
# Life insurance
# On-site parking
# Paid training
# Promotion to permanent employee
# Transportation service provided
# 8 hour shift
# Day shift
# 13th month salary
# Overtime pay
# Understand consumer needs and ensure that the elements developed by the team will contribute to player satisfaction and enjoyment
# Work with project managers to determine and assess project scope, production capacity and set priorities for the team
# Work with artists and programmers to ensure proper implementation of the game features designed
# Delegate tasks and track the progress of the team’s deliverables
# Communicate project objectives and strategies to team members
# Provide clear and structured project documents to ensure that gameplay intentions are understood
# Actively participate in the decision-making process with management and oversee the necessary adjustments to ensure that the team meets expectations
# Create a work environment that is motivating for team members and which fosters development and creation
# Support career advancement and suggest development and interpersonal skills training and techniques sessions to team members
# Carry out performance follow ups and assessments
# Participate in the selection of team members
# Any other ad-hoc duties, if necessary
#
# Must have shipped at least 2 AAA games as a Lead or Senior Game Designer role
# Has experience in leading a multidisciplinary team
# Excellent communication and interpersonal skills
# Strong management and planning skills
# Highly organized and analytical
# Excellent management and planning skills
# Proactive and enthusiastic team player
# Solution oriented and ability to work effectively under pressure
# Passionate about playing and creating games
# Candidate must possess at least a Bachelor's/College Degree , any field.
# At least 1 year(s) of working experience in the related field is required for this position.
# Preferably 1-4 Yrs Experienced Employees specializing in IT/Computer - Network/System/Database Admin or equivalent.
# Full-Time position(s) available.
# Enhance product functionality
# Maintain quality
# Achieve Company Target
# Computer Hardward/ Software Troubleshooting
# With experience on the following:
# Sketch
# Invision studio
# Axure
# Craft
# Photo.io
# Adobe XD
# Marvel
# Figma
# Framer X
# Webflow
# Create enhancement logic useful to users and product (Target increase active player, transaction & Playtime)
# Competitor Survey & Report
# Coordinate with Internal & external to solve any product matters
# Maintain Product Quality (UAT)
# Report Documentation via axure software
# 10 hour shift
# Company Christmas gift
# Company events
# Free parking
# Health insurance
# Life insurance
# On-site parking
# Paid training
# Promotion to permanent employee
# Transportation service provided
# 8 hour shift
# Day shift
# 13th month salary
# Overtime pay
# Understand consumer needs and ensure that the elements developed by the team will contribute to player satisfaction and enjoyment
# Work with project managers to determine and assess project scope, production capacity and set priorities for the team
# Work with artists and programmers to ensure proper implementation of the game features designed
# Delegate tasks and track the progress of the team’s deliverables
# Communicate project objectives and strategies to team members
# Provide clear and structured project documents to ensure that gameplay intentions are understood
# Actively participate in the decision-making process with management and oversee the necessary adjustments to ensure that the team meets expectations
# Create a work environment that is motivating for team members and which fosters development and creation
# Support career advancement and suggest development and interpersonal skills training and techniques sessions to team members
# Carry out performance follow ups and assessments
# Participate in the selection of team members
# Any other ad-hoc duties, if necessary
#
# Must have shipped at least 2 AAA games as a Lead or Senior Game Designer role
# Has experience in leading a multidisciplinary team
# Excellent communication and interpersonal skills
# Strong management and planning skills
# Highly organized and analytical
# Excellent management and planning skills
# Proactive and enthusiastic team player
# Solution oriented and ability to work effectively under pressure
# Passionate about playing and creating games
# Candidate must possess at least a Bachelor's/College Degree , any field.
# At least 1 year(s) of working experience in the related field is required for this position.
# Preferably 1-4 Yrs Experienced Employees specializing in IT/Computer - Network/System/Database Admin or equivalent.
# Full-Time position(s) available.
# Enhance product functionality
# Maintain quality
# Achieve Company Target
# Computer Hardward/ Software Troubleshooting
# With experience on the following:
# Sketch
# Invision studio
# Axure
# Craft
# Photo.io
# Adobe XD
# Marvel
# Figma
# Framer X
# Webflow
# Create enhancement logic useful to users and product (Target increase active player, transaction & Playtime)
# Competitor Survey & Report
# Coordinate with Internal & external to solve any product matters
# Maintain Product Quality (UAT)
# Report Documentation via axure software
# 10 hour shift
# Company Christmas gift
# Company events
# Free parking
# Health insurance
# Life insurance
# On-site parking
# Paid training
# Promotion to permanent employee
# Transportation service provided
# 8 hour shift
# Day shift
# 13th month salary
# Overtime pay
# Understand consumer needs and ensure that the elements developed by the team will contribute to player satisfaction and enjoyment
# Work with project managers to determine and assess project scope, production capacity and set priorities for the team
# Work with artists and programmers to ensure proper implementation of the game features designed
# Delegate tasks and track the progress of the team’s deliverables
# Communicate project objectives and strategies to team members
# Provide clear and structured project documents to ensure that gameplay intentions are understood
# Actively participate in the decision-making process with management and oversee the necessary adjustments to ensure that the team meets expectations
# Create a work environment that is motivating for team members and which fosters development and creation
# Support career advancement and suggest development and interpersonal skills training and techniques sessions to team members
# Carry out performance follow ups and assessments
# Participate in the selection of team members
# Any other ad-hoc duties, if necessary
#
# Must have shipped at least 2 AAA games as a Lead or Senior Game Designer role
# Has experience in leading a multidisciplinary team
# Excellent communication and interpersonal skills
# Strong management and planning skills
# Highly organized and analytical
# Excellent management and planning skills
# Proactive and enthusiastic team player
# Solution oriented and ability to work effectively under pressure
# Passionate about playing and creating games
# Candidate must possess at least a Bachelor's/College Degree , any field.
# At least 1 year(s) of working experience in the related field is required for this position.
# Preferably 1-4 Yrs Experienced Employees specializing in IT/Computer - Network/System/Database Admin or equivalent.
# Full-Time position(s) available.
# Enhance product functionality
# Maintain quality
# Achieve Company Target
# Computer Hardward/ Software Troubleshooting
# With experience on the following:
# Sketch
# Invision studio
# Axure
# Craft
# Photo.io
# Adobe XD
# Marvel
# Figma
# Framer X
# Webflow
# Create enhancement logic useful to users and product (Target increase active player, transaction & Playtime)
# Competitor Survey & Report
# Coordinate with Internal & external to solve any product matters
# Maintain Product Quality (UAT)
# Report Documentation via axure software
# 10 hour shift
# Company Christmas gift
# Company events
# Free parking
# Health insurance
# Life insurance
# On-site parking
# Paid training
# Promotion to permanent employee
# Transportation service provided
# 8 hour shift
# Day shift
# 13th month salary
# Overtime pay
# Understand consumer needs and ensure that the elements developed by the team will contribute to player satisfaction and enjoyment
# Work with project managers to determine and assess project scope, production capacity and set priorities for the team
# Work with artists and programmers to ensure proper implementation of the game features designed
# Delegate tasks and track the progress of the team’s deliverables
# Communicate project objectives and strategies to team members
# Provide clear and structured project documents to ensure that gameplay intentions are understood
# Actively participate in the decision-making process with management and oversee the necessary adjustments to ensure that the team meets expectations
# Create a work environment that is motivating for team members and which fosters development and creation
# Support career advancement and suggest development and interpersonal skills training and techniques sessions to team members
# Carry out performance follow ups and assessments
# Participate in the selection of team members
# Any other ad-hoc duties, if necessary
#
# Must have shipped at least 2 AAA games as a Lead or Senior Game Designer role
# Has experience in leading a multidisciplinary team
# Excellent communication and interpersonal skills
# Strong management and planning skills
# Highly organized and analytical
# Excellent management and planning skills
# Proactive and enthusiastic team player
# Solution oriented and ability to work effectively under pressure
# Passionate about playing and creating games
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jvrosario/Documents/internship/husay_project_task/Data Analysis/analysis_director_indeed copy.ipynb Cell 14' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/Users/jvrosario/Documents/internship/husay_project_task/Data%20Analysis/analysis_director_indeed%20copy.ipynb#ch0000013?line=0'>1</a> for i in range(len(merge["Qualification"])):
# ----> <a href='vscode-notebook-cell:/Users/jvrosario/Documents/internship/husay_project_task/Data%20Analysis/analysis_director_indeed%20copy.ipynb#ch0000013?line=1'>2</a>     a_list = literal_eval(merge["Qualification"][i])
#       <a href='vscode-notebook-cell:/Users/jvrosario/Documents/internship/husay_project_task/Data%20Analysis/analysis_director_indeed%20copy.ipynb#ch0000013?line=2'>3</a>     for j in range(len(a_list)):
#       <a href='vscode-notebook-cell:/Users/jvrosario/Documents/internship/husay_project_task/Data%20Analysis/analysis_director_indeed%20copy.ipynb#ch0000013?line=3'>4</a>         print(a_list[j])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py:108, in literal_eval(node_or_string)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=105'>106</a>                 return left - right
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=106'>107</a>     return _convert_signed_num(node)
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=107'>108</a> return _convert(node_or_string)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py:107, in literal_eval.<locals>._convert(node)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=104'>105</a>         else:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=105'>106</a>             return left - right
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=106'>107</a> return _convert_signed_num(node)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py:81, in literal_eval.<locals>._convert_signed_num(node)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=78'>79</a>     else:
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=79'>80</a>         return - operand
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=80'>81</a> return _convert_num(node)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py:72, in literal_eval.<locals>._convert_num(node)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=69'>70</a> def _convert_num(node):
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=70'>71</a>     if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=71'>72</a>         _raise_malformed_node(node)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=72'>73</a>     return node.value
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py:69, in literal_eval.<locals>._raise_malformed_node(node)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=66'>67</a> if lno := getattr(node, 'lineno', None):
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=67'>68</a>     msg += f' on line {lno}'
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ast.py?line=68'>69</a> raise ValueError(msg + f': {node!r}')
#
# ValueError: malformed node or string: nan
