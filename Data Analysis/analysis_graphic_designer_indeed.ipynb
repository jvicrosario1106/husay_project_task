# %%
import matplotlib.pyplot as plt
import pandas as pd
from ast import literal_eval
import re

# %%
merge = pd.concat(map(pd.read_csv, ["../Raw_CSV/April 25-26 - 2022/Indeed/Indeed-graphic designer.csv","../Raw_CSV/April 27 - 2022/Indeed/Indeed-graphic designer.csv", "../Raw_CSV/April 28 - 2022/Indeed/Indeed-graphic-designer.csv","../Raw_CSV/April 21-22 - 2022/Indeed/graphic-designer.csv"]),ignore_index=True)

# %%
#Describing the data
merge.describe()
# Out:
#                       Title           Company SalaryOne SalaryTwo  \
# count                   307               307       262       262
# unique                   90               132        42        24
# top     newGraphic Designer  Assassin's Creed      None      None
# freq                     41                13       179       205
#
#                 Location                              Summary Qualification  \
# count                307                                  307           262
# unique                44                                  127           121
# top     Remote in Manila  Test graphics across various media.            []
# freq                  53                                   17            21
#
#        Role&Responsibilities
# count                    262
# unique                   119
# top                       []
# freq                      26

# %%
#View Data's
merge
# Out:
#                                       Title  \
# 0                Freelance Graphic Reviewer
# 1    newGraphic Designer | Jr. to Sr. Level
# 2                          Graphic Designer
# 3                       newGraphic Designer
# 4                       newGraphic Designer
# ..                                      ...
# 302                     newGraphic Designer
# 303                     newGRAPHIC DESIGNER
# 304                        Graphic Designer
# 305                 Graphic Artist/Designer
# 306                        Graphic Designer
#
#                                                Company  \
# 0                                                Canva
# 1                                              Lumenvo
# 2                           Freedom Property Investors
# 3                             Pristines Solutions Inc.
# 4                    Training Vision Institute Pte Ltd
# ..                                                 ...
# 302               Instalimb Solutions Philippines Inc.
# 303                          Sucree Coco and Love Inc.
# 304                                  Skyrocket Studios
# 305                             Omni Channel Solutions
# 306  Kareila Management Corporation (S&R Membership...
#
#                            SalaryOne SalaryTwo               Location  \
# 0                               None      None       Remote in Manila
# 1    PHP 30,000 - PHP 40,000 a month      None       Remote in Manila
# 2    PHP 30,000 - PHP 40,000 a month      None                 Remote
# 3    PHP 30,000 - PHP 50,000 a month      None                 Makati
# 4                 PHP 25,000 a month      None       Remote in Makati
# ..                               ...       ...                    ...
# 302                              NaN       NaN                 Makati
# 303                              NaN       NaN  Remote in Quezon City
# 304                              NaN       NaN                 Makati
# 305                              NaN       NaN        Remote in Pasig
# 306                              NaN       NaN                 Makati
#
#                                                Summary  \
# 0    Professional portfolio of projects showing exc...
# 1    Proficient in graphic editing software such as...
# 2    Work with a wide range of media and use graphi...
# 3                  Test graphics across various media.
# 4    Must have at least 3 years of experience in de...
# ..                                                 ...
# 302  E.g. promo, product posts, announce of holiday...
# 303         Temporary on a Work from Home Arrangement.
# 304  Leading and contributing to design projects fr...
# 305  You execute creative activities through the ov...
# 306  Graduate of Fine Arts, Multimedia Art or equiv...
#
#                                          Qualification  \
# 0    ['\nReview graphics in a high-volume, deadline...
# 1    ['Must have knowledge of Website Design', 'Gra...
# 2    ['Create and design various materials for prin...
# 3    ['Study design briefs and determine requiremen...
# 4    ['Project-based', 'Part-time', 'Work from home...
# ..                                                 ...
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
#
#                                  Role&Responsibilities
# 0    ['', 'Canva’s Commitment and Mission', '\nAt C...
# 1    ['Show off your creativity and enhance your sk...
# 2    ['About the role:', 'The role is placed with t...
# 3    ['Graphic designers create visual text and ima...
# 4    ['We are looking for a brand designer who can ...
# ..                                                 ...
# 302                                                NaN
# 303                                                NaN
# 304                                                NaN
# 305                                                NaN
# 306                                                NaN
#
# [307 rows x 8 columns]

# %%
location = merge["Location"].value_counts()[0:10] # Location
salary = merge["SalaryOne"] + " " + merge["SalaryTwo"] # Salary
title = merge["Title"].value_counts()[0:10]

# %%
location.to_frame()
# Out:
#                   Location
# Remote in Manila        53
# Makati                  46
# Santa Rosa City         26
# Remote                  24
# Pasay                   21
# Manila                  18
# Santo Tomas             13
# Remote in Makati        11
# Remote in Pasig         10
# Quezon City              9

# %%
plt.bar(location.index, location.values,width=0.3)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
title.to_frame()
# Out:
#                                                     Title
# newGraphic Designer                                    41
# Graphic Designer                                       33
# Lead Game Designer                                     26
# Game Designer                                          13
# newGame Designer                                       13
# Graphic Artist                                          8
# Graphic Artist/Designer                                 7
# Graphic Designer under Branding                         6
# Junior Graphic Designer                                 6
# Junior Graphic Designer for Aussie Agency - Wor...      6

# %%
plt.bar(title.index, title.values,width=0.3,)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
company = merge["Company"].value_counts()[0:10]

# %%
company.to_frame()
# Out:
#                                            Company
# Assassin's Creed                                13
# Ubisoft                                         13
# Aruze Global Shared Services Philippines        13
# Onward Worldwide Management & Consultancy       13
# FiltaGlobal                                     10
# Canva                                           10
# MARQUE                                           6
# Lumenvo                                          5
# AIRCLASS (PHILIPPINES) CORP.                     5
# IKEA                                             5

# %%
plt.bar(company.index, company.values)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
replace = merge["Qualification"].str.replace("^\['|'\]$","")
# Out:
# /var/folders/tc/qdg72rpx523gjsqcr2vf_0c00000gn/T/ipykernel_3775/1200321832.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   replace = merge["Qualification"].str.replace("^\['|'\]$","")

# %%
for i in range(len(merge["Qualification"])):
    a_list = literal_eval(merge["Qualification"][i])
    for j in range(len(a_list)):
        print(a_list[j])
