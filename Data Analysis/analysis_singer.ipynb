# %%
import matplotlib.pyplot as plt
import pandas as pd
from ast import literal_eval
import re

# %%
merge = pd.concat(map(pd.read_csv, ["../Raw_CSV/April 25-26 - 2022/Indeed/Indeed-singer.csv","../Raw_CSV/April 27 - 2022/Indeed/Indeed-singer.csv", "../Raw_CSV/April 28 - 2022/Indeed/Indeed-singer.csv","../Raw_CSV/April 21-22 - 2022/Indeed/singer.csv"]),ignore_index=True)

# %%
#Describing the data
merge.describe()
# Out:
#                       Title  Company SalaryOne SalaryTwo  \
# count                   296      296       260       260
# unique                   13        6         6         6
# top     Singer & Promodiser  Volopay      None      None
# freq                     26      104       192       236
#
#                                  Location  \
# count                                 296
# unique                                 11
# top     Remote in National Capital Region
# freq                                  104
#
#                                                   Summary     Qualification  \
# count                                                 296               260
# unique                                                  9                16
# top     Volopay is a Y Combinator-backed start-up that...  ['8 hour shift']
# freq                                                   78                45
#
#                        Role&Responsibilities
# count                                    260
# unique                                    17
# top     ['Job Type: Full-time', 'Schedule:']
# freq                                      32

# %%
#View Data's
merge
# Out:
#                                 Title  \
# 0                 Singer & Promodiser
# 1                   SINGER PROMODISER
# 2                   Singer Promodiser
# 3    Sales Manager - Virtual Position
# 4           Singer Promodiser (DAVAO)
# ..                                ...
# 291  Sales Development Representative
# 292             Talent Director Sales
# 293   Choir Conductor and Band Master
# 294             Sales Account Manager
# 295        Backend Software Developer
#
#                                        Company SalaryOne  \
# 0                     Kings Group of Companies      None
# 1             VISMAY INTERNATIONAL CORPORATION      None
# 2                         Ets2 Resource Center      None
# 3    Barbizon Modeling School of Manhattan Inc      None
# 4             VISMAY INTERNATIONAL CORPORATION      None
# ..                                         ...       ...
# 291                                    Volopay       NaN
# 292  Barbizon Modeling School of Manhattan Inc       NaN
# 293                    City College of Angeles       NaN
# 294                                    Volopay       NaN
# 295                                    Volopay       NaN
#
#                           SalaryTwo                           Location  \
# 0                              None                  Pasig+5 locations
# 1                PHP 11,000 a month               Cebu City+1 location
# 2                PHP 14,007 a month                  Manila+1 location
# 3                              None                   Remote in Taguig
# 4    PHP 9,000 - PHP 10,000 a month                         Davao City
# ..                              ...                                ...
# 291                             NaN  Remote in National Capital Region
# 292                             NaN           Remote in Fort Bonifacio
# 293                             NaN                            Angeles
# 294                             NaN  Remote in National Capital Region
# 295                             NaN  Remote in National Capital Region
#
#                                                Summary  \
# 0    Candidate must possess at least High School gr...
# 1    Candidate must possess at least Vocational Dip...
# 2    The jobholder is responsible for selling produ...
# 3                   Barbizon MODELING School of NYC *.
# 4    VISMAY INTERNATIONAL CORPORATION IS IN NEED OF...
# ..                                                 ...
# 291  Volopay is a Y Combinator-backed start-up that...
# 292   No cold calling, a full-time permanent position.
# 293      At least one year of related work experience.
# 294  Volopay is a Y Combinator backed startup that ...
# 295  Volopay is a Y Combinator-backed start-up that...
#
#                                          Qualification  \
# 0    ['Candidate must possess at least High School ...
# 1    ['Candidate must possess at least High School ...
# 2    ['· Greets and receives customers in a welcomi...
# 3    ['Paid training', 'Work from home', '8 hour sh...
# 4                                     ['8 hour shift']
# ..                                                 ...
# 291                                                NaN
# 292                                                NaN
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
#
#                                  Role&Responsibilities
# 0                 ['Job Type: Full-time', 'Schedule:']
# 1                 ['Job Type: Full-time', 'Schedule:']
# 2    ['I. Job Objective/s: ', 'The jobholder is res...
# 3    ['Barbizon MODELING School of NYC VIRTUAL SALE...
# 4    ['Job description', 'VISMAY INTERNATIONAL CORP...
# ..                                                 ...
# 291                                                NaN
# 292                                                NaN
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
#
# [296 rows x 8 columns]

# %%
location = merge["Location"].value_counts()[0:10] # Location
salary = merge["SalaryOne"] + " " + merge["SalaryTwo"] # Salary
title = merge["Title"].value_counts()[0:10]

# %%
location.to_frame()
# Out:
#                                    Location
# Remote in National Capital Region       104
# Manila+1 location                        26
# Remote in Taguig                         26
# Davao City                               26
# Batangas City                            26
# Angeles                                  26
# Cebu City+1 location                     20
# Pasig+5 locations                        16
# Remote in Fort Bonifacio                 10
# Manila+5 locations                       10

# %%
plt.bar(location.index, location.values,width=0.3)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
title.to_frame()
# Out:
#                                   Title
# Singer & Promodiser                  26
# Singer Promodiser                    26
# Sales Manager - Virtual Position     26
# Singer Promodiser (DAVAO)            26
# SINGER PROMODISER (BATANGAS)         26
# Sales Development Representative     26
# Inside Sales Representative          26
# Backend Software Developer           26
# Choir Conductor and Band Master      26
# Sales Account Manager                26

# %%
plt.bar(title.index, title.values,width=0.3,)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
company = merge["Company"].value_counts()[0:10]

# %%
company.to_frame()
# Out:
#                                            Company
# Volopay                                        104
# VISMAY INTERNATIONAL CORPORATION                78
# Barbizon Modeling School of Manhattan Inc       36
# Kings Group of Companies                        26
# Ets2 Resource Center                            26
# City College of Angeles                         26

# %%
plt.bar(company.index, company.values)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
replace = merge["Qualification"].str.replace("^\['|'\]$","")
# Out:
# /var/folders/tc/qdg72rpx523gjsqcr2vf_0c00000gn/T/ipykernel_4242/1200321832.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   replace = merge["Qualification"].str.replace("^\['|'\]$","")

# %%
for i in range(len(merge["Qualification"])):
    a_list = literal_eval(merge["Qualification"][i])
    for j in range(len(a_list)):
        #print(a_list[j])
# Out:
#   Input In [14]
#     #print(a_list[j])
#                      ^
# SyntaxError: incomplete input
