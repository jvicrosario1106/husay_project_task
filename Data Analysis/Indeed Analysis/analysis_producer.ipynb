# %%
import matplotlib.pyplot as plt
import pandas as pd
from ast import literal_eval
import re

# %%
merge = pd.concat(map(pd.read_csv, ["../../Raw_CSV/April 25-26 - 2022/Indeed/Indeed-producer.csv","../../Raw_CSV/April 27 - 2022/Indeed/Indeed-producer.csv", "../../Raw_CSV/April 28 - 2022/Indeed/Indeed-producer.csv","../../Raw_CSV/April 21-22 - 2022/Indeed/producer.csv"]),ignore_index=True)

# %%
#Describing the data
merge.describe()
# Out:
#            Title            Company SalaryOne SalaryTwo Location  \
# count        390                390       345       345      390
# unique       137                 94        19        15       41
# top     Producer  GMA Network, Inc.      None      None   Manila
# freq          14                 19       296       323       69
#
#                                                   Summary Qualification  \
# count                                                 390           345
# unique                                                138           130
# top     Manages the end-to-end production of assigned ...            []
# freq                                                   14            68
#
#        Role&Responsibilities
# count                    345
# unique                   104
# top                       []
# freq                     109

# %%
#View Data's
merge
# Out:
#                                                  Title  \
# 0                                 Banking Staff Writer
# 1    newStaff Writer - Office Technology Content (R...
# 2                                   Video Editor (WFH)
# 3                                     Content Producer
# 4                                       Video Producer
# ..                                                 ...
# 385                                   Content Producer
# 386                                     Sound Engineer
# 387                    Segment Producer (Halalan 2022)
# 388                       Medical Sales Representative
# 389                                   Content Producer
#
#                                  Company           SalaryOne SalaryTwo  \
# 0                   FitSmallBusiness.com  PHP 52,185 a month      None
# 1                   FitSmallBusiness.com  PHP 52,000 a month      None
# 2    Eastvantage Business Solutions Inc.                None      None
# 3                      GMA Network, Inc.                None      None
# 4                      GMA Network, Inc.                None      None
# ..                                   ...                 ...       ...
# 385   STI Education Services Group, Inc.                 NaN       NaN
# 386                    Chupana Marketing                 NaN       NaN
# 387                  ABS-CBN Corporation                 NaN       NaN
# 388                                IQVIA                 NaN       NaN
# 389                        LOSTUDIOS Inc                 NaN       NaN
#
#                   Location                                            Summary  \
# 0    Remote in Philippines  The Banking Staff Writer role creates content ...
# 1    Remote in Philippines  Job Overview: * The Office Technology Content ...
# 2         Remote in Taguig  You will be required to edit YouTube video con...
# 3                   Manila  A.) College graduate, preferably with a degree...
# 4                   Manila  The Video Producer captures/records videos and...
# ..                     ...                                                ...
# 385                 Cainta  Responsible for creating and producing compell...
# 386       Remote in Manila  Responsible for amplifying, enhancing, mixing ...
# 387            Philippines  Supervise the coverage of a segment and act as...
# 388            Philippines  Targets, promotes, and sells specialized produ...
# 389    Remote in Las Piñas  Manages the end-to-end production of assigned ...
#
#                                          Qualification  \
# 0    ['Writes publishable first drafts of 3–4 artic...
# 1    ['Write publishable first drafts of 2–4 articl...
# 2    ['You will be required to edit YouTube video c...
# 3                                                   []
# 4    [' College graduate', ' Skilled in camera work...
# ..                                                 ...
# 385                                                NaN
# 386                                                NaN
# 387                                                NaN
# 388                                                NaN
# 389                                                NaN
#
#                                  Role&Responsibilities
# 0    ['The Banking Staff Writer role creates conten...
# 1    ['Job Overview:  The Office Technology Content...
# 2                                                   []
# 3                                                 ['']
# 4                                                 ['']
# ..                                                 ...
# 385                                                NaN
# 386                                                NaN
# 387                                                NaN
# 388                                                NaN
# 389                                                NaN
#
# [390 rows x 8 columns]

# %%
location = merge["Location"].value_counts()[0:10] # Location
salary = merge["SalaryOne"] + " " + merge["SalaryTwo"] # Salary
title = merge["Title"].value_counts()[0:10]

# %%
location.to_frame()
# Out:
#                      Location
# Manila                     69
# Remote in Manila           43
# Taguig                     39
# Quezon City                30
# Philippines                26
# Makati                     16
# Remote                     15
# Laguna                     14
# Remote in Las Piñas        14
# Santa Rosa City            11

# %%
plt.bar(location.index, location.values,width=0.3)
plt.title("Indeed Producer Location")
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
title.to_frame()
# Out:
#                                            Title
# Producer                                      14
# Content Producer                              11
# Video Producer                                11
# Sound Engineer                                 9
# Executive Producer                             9
# Full-time Content Producer (Social Media)      9
# 09 - Content Producer (HomeBased)              8
# Creative Content Producer                      8
# 07 - Content creator/ producer                 7
# Sr. Production Manager                         7

# %%
plt.barh(title.index, title.values)
plt.title("Indeed Producer")
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
company = merge["Company"].value_counts()[0:10]

# %%
company.to_frame()
# Out:
#                                             Company
# GMA Network, Inc.                                19
# ABS-CBN Corporation                              17
# Support Shepherd                                 15
# LOSTUDIOS Inc                                    14
# James Hardie Australia                           14
# Fil-Chi Media Productions Inc. (Chinoy TV)       12
# Canva                                            12
# Code and Theory                                  10
# Ubisoft                                           9
# IH Digital                                        9

# %%
plt.bar(company.index, company.values)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
replace = merge["Qualification"].str.replace("^\['|'\]$","")
# Out:
# /var/folders/tc/qdg72rpx523gjsqcr2vf_0c00000gn/T/ipykernel_2498/1200321832.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   replace = merge["Qualification"].str.replace("^\['|'\]$","")

# %%
for i in range(len(merge["Qualification"])):
    a_list = literal_eval(merge["Qualification"][i])
    for j in range(len(a_list)):
        #print(a_list[j])
# Out:
#   Input In [14]
#     #print(a_list[j])
#                      ^
# SyntaxError: incomplete input
