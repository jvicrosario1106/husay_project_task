# %%
import matplotlib.pyplot as plt
import pandas as pd
from ast import literal_eval
import re

# %%
merge = pd.concat(map(pd.read_csv, ["../../Raw_CSV/April 25-26 - 2022/Indeed/Indeed-illustrator.csv","../../Raw_CSV/April 27 - 2022/Indeed/Indeed-illustrator.csv", "../../Raw_CSV/April 28 - 2022/Indeed/Indeed-illustrator.csv","../../Raw_CSV/April 21-22 - 2022/Indeed/illustrator.csv"]),ignore_index=True)

# %%
#Describing the data
merge.describe()
# Out:
#                       Title Company SalaryOne SalaryTwo          Location  \
# count                   330     330       285       285               330
# unique                  106     113         1        44                55
# top     newGraphic Designer   Canva      None      None  Remote in Manila
# freq                     42      31       285       139                73
#
#                                                   Summary Qualification  \
# count                                                 330           285
# unique                                                120           130
# top     These elements play a big part in creating goo...            []
# freq                                                   12            10
#
#                                     Role&Responsibilities
# count                                                 285
# unique                                                136
# top     ['Be our expert in producing appealing listing...
# freq                                                    9

# %%
#View Data's
merge
# Out:
#                                                  Title  \
# 0                       Freelance Illustrator - Manila
# 1                                       newIllustrator
# 2    newConcept Artist/ Illustrator (apply with por...
# 3            newHomebased Promotional Graphic Designer
# 4                             Illustrator- BPO Company
# ..                                                 ...
# 325  newSenior Graphic Designer - Packaging (Freela...
# 326             Graphic Artist - Can start immediately
# 327   2D Graphic Artist (Concept Artist / Illustrator)
# 328    Shopee Xpress - Partnerships (Graphic Designer)
# 329                              07 - Graphic Designer
#
#                                           Company SalaryOne  \
# 0                                           Canva      None
# 1                                Vibal Group Inc.      None
# 2                    AIRCLASS (PHILIPPINES) CORP.      None
# 3                                     DCX PH Inc.      None
# 4                             Bershaw Consultancy      None
# ..                                            ...       ...
# 325                                         Perch       NaN
# 326                 CWC International Corporation       NaN
# 327  Overcast Games Software Development Services       NaN
# 328                                        Shopee       NaN
# 329                              Support Shepherd       NaN
#
#                            SalaryTwo          Location  \
# 0                               None  Remote in Manila
# 1                               None       Quezon City
# 2    PHP 30,000 - PHP 50,000 a month  Remote in Manila
# 3    PHP 35,000 - PHP 40,000 a month  Remote in Manila
# 4    PHP 40,000 - PHP 90,000 a month             Pasay
# ..                               ...               ...
# 325                              NaN  Remote in Manila
# 326                              NaN            Makati
# 327                              NaN            Taytay
# 328                              NaN            Manila
# 329                              NaN  Remote in Manila
#
#                                                Summary  \
# 0     Vectors play a big part in creating good design.
# 1     Fine arts or any design related course graduate.
# 2    Creates and develops concepts for characters a...
# 3    The Home Based Sales Product Artist will work ...
# 4    Have at least 3-5 years of work experience, wi...
# ..                                                 ...
# 325  We are a key resource for entrepreneurs who wa...
# 326  Must be able to use various graphic design sof...
# 327          Being a good anime illustrator is a plus.
# 328  The Operation teams at Shopee covers the opera...
# 329  We're looking for a highly creative graphic de...
#
#                                          Qualification  \
# 0    ['\n\n\n\n            Produce illustrations in...
# 1    ['Fine arts or any design related course gradu...
# 2    ['Creates and develops concepts for characters...
# 3    ['Can handle an array of projects at any given...
# 4    ['Art and Game Design in Gaming Industry: 3 ye...
# ..                                                 ...
# 325                                                NaN
# 326                                                NaN
# 327                                                NaN
# 328                                                NaN
# 329                                                NaN
#
#                                  Role&Responsibilities
# 0    ['', 'Canva’s Commitment and Mission', ' At Ca...
# 1    ['Job description', 'Job Type: Full-time', 'Sc...
# 2    ['Responsibilities: ', 'Qualifications: ', 'Sk...
# 3    ["The Home Based Sales Product Artist will wor...
# 4    ['Job Responsibility & Qualifications:', '1. H...
# ..                                                 ...
# 325                                                NaN
# 326                                                NaN
# 327                                                NaN
# 328                                                NaN
# 329                                                NaN
#
# [330 rows x 8 columns]

# %%
location = merge["Location"].value_counts()[0:10] # Location
salary = merge["SalaryOne"] + " " + merge["SalaryTwo"] # Salary
title = merge["Title"].value_counts()[0:10]

# %%
location.to_frame()
# Out:
#                               Location
# Remote in Manila                    73
# Pasay                               26
# Makati                              24
# Manila                              19
# Remote in Pasig                     17
# Quezon City                         17
# Taguig                              12
# Remote in Makati                    11
# Remote                              10
# Remote in Makati+2 locations         8

# %%
plt.bar(location.index, location.values,width=0.3)
plt.title("Indeed Illustrator Location")
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
title.to_frame()
# Out:
#                                            Title
# newGraphic Designer                           42
# newGraphic Artist                             25
# Graphic Artist                                21
# PERMANENT REMOTE WORK | Graphic Associate     11
# Illustrator                                   10
# Graphic Designer                               7
# Freelance Graphic Reviewer                     7
# newJunior Brand Designer                       5
# Motion Graphics Reviewer                       5
# newGraphic Illustrator                         5

# %%
plt.barh(title.index, title.values)
plt.title("Indeed Illustrator")
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
company = merge["Company"].value_counts()[0:10]

# %%
company.to_frame()
# Out:
#                               Company
# Canva                              31
# CommerceLabs                       11
# Support Shepherd                    7
# DIY HARDWARE                        7
# AIRCLASS (PHILIPPINES) CORP.        6
# P2EBoard                            6
# Extenteam                           6
# HPL Gamedesign Corporation          6
# Relotz                              6
# LICA Land                           5

# %%
plt.bar(company.index, company.values)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
replace = merge["Qualification"].str.replace("^\['|'\]$","")
# Out:
# /var/folders/tc/qdg72rpx523gjsqcr2vf_0c00000gn/T/ipykernel_2409/1200321832.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   replace = merge["Qualification"].str.replace("^\['|'\]$","")

# %%
for i in range(len(merge["Qualification"])):
    a_list = literal_eval(merge["Qualification"][i])
    for j in range(len(a_list)):
        #print(a_list[j])
# Out:
#   Input In [28]
#     #print(a_list[j])
#                      ^
# SyntaxError: incomplete input
