# %%
import matplotlib.pyplot as plt
import pandas as pd
from ast import literal_eval
import re

# %%
merge = pd.concat(map(pd.read_csv, ["../../Raw_CSV/April 25-26 - 2022/Indeed/Indeed-creative director.csv","../../Raw_CSV/April 27 - 2022/Indeed/Indeed-creative director.csv", "../../Raw_CSV/April 28 - 2022/Indeed/Indeed-creative-director.csv","../../Raw_CSV/April 21-22 - 2022/Indeed/creative-director.csv"]),ignore_index=True)

# %%
#Describing the data
merge.describe()
# Out:
#                     Title                       Company SalaryOne SalaryTwo  \
# count                 375                           375       330       330
# unique                150                           142         1        34
# top     Creative Director  Unlimited Design Philippines      None      None
# freq                   40                            16       330       231
#
#        Location                                            Summary  \
# count       375                                                375
# unique       40                                                154
# top      Manila  Proven superior design skills and creative tal...
# freq         54                                                 18
#
#        Qualification Role&Responsibilities
# count            330                   330
# unique           178                   164
# top               []                    []
# freq              49                    80

# %%
#View Data's
merge
# Out:
#                                  Title                       Company  \
# 0                    Creative Director  Unlimited Design Philippines
# 1                    Creative Director              FleishmanHillard
# 2      Creative Director - Work Remote           GoBeyondStudios,Inc
# 3          Associate Creative Director                        ogilvy
# 4       newCreative Operations Manager                   FreshPrints
# ..                                 ...                           ...
# 370                      Creative Lead                     August 99
# 371  Associate Director, Agency Impact                           AIA
# 372                Senior Art Director    AXIATA DIGITAL & ANALYTICS
# 373        newWavemaker | Art Director                        GroupM
# 374           5G Core Program Director                      Ericsson
#
#     SalaryOne                         SalaryTwo                      Location  \
# ...

# %%
location = merge["Location"].value_counts()[0:10] # Location
salary = merge["SalaryOne"] + " " + merge["SalaryTwo"] # Salary
title = merge["Title"].value_counts()[0:10]

# %%
location.to_frame()
# Out:
#                   Location
# Manila                  54
# Makati                  51
# Remote in Manila        45
# Remote                  30
# Remote in Makati        22
# Taguig                  20
# Ortigas                 16
# Pasig                   16
# Philippines             15
# Quezon City             14

# %%
plt.bar(location.index, location.values,width=0.3)
plt.title("Indeed Creative Director Location")
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
title.to_frame()
# Out:
#                                        Title
# Creative Director                         40
# Art Director                              24
# newGraphic Designer                        8
# newCreative Director                       7
# Digital Art Director                       6
# 04- Creative Director / Lead Designer      6
# newART DIRECTOR                            6
# Copywriter                                 5
# newContent Associate                       5
# Graphic Artist                             5

# %%
plt.barh(title.index, title.values)
plt.title("Indeed Creative Director")
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
company = merge["Company"].value_counts()[0:10]

# %%
company.to_frame()
# Out:
#                                       Company
# Unlimited Design Philippines               16
# Ogilvy                                     14
# Canva                                      13
# Support Shepherd                           12
# Lennor Metier Consulting Philippines        8
# Transbiz                                    8
# Wide-out Workforces Inc.                    7
# Code and Theory                             6
# Tagline Group Of Companies                  6
# kumu                                        6

# %%
plt.bar(company.index, company.values)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
replace = merge["Qualification"].str.replace("^\['|'\]$","")
# Out:
# /var/folders/tc/qdg72rpx523gjsqcr2vf_0c00000gn/T/ipykernel_2340/1200321832.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   replace = merge["Qualification"].str.replace("^\['|'\]$","")

# %%
for i in range(len(merge["Qualification"])):
    a_list = literal_eval(merge["Qualification"][i])
    for j in range(len(a_list)):
        print(a_list[j])
# Out:
# Work with the CEO and Creative Design and Digital teams to produce new ideas for branding, designs, campaigns, npd, websites and marketing communications.
# Direct and lead brainstorming meetings, workshops and creative sessions both internally and with clients.
# Visually translate high level strategies into award winning creative execution, ideation and conceptual. Getting on the tools as required to lead by example.
# Shape and drive internal standards and create procedures to ensure all products and deliverables are consistently of a very high standard.
# Minimum 10+ years' experience as CD in a similar (integrated) role and environment - B2B, Retail or FMCG expertise required
# Strong leadership and organisational skills and ability to guide teams
# Excellent time management skills and the ability to work under pressure and meet deadlines - fast turnaround times.
# Great communication and client liaison skills
# String Retail understating
# ...
