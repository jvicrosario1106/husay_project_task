# %%
import matplotlib.pyplot as plt
import pandas as pd
from ast import literal_eval
import re

# %%
merge = pd.concat(map(pd.read_csv, ["../../Raw_CSV/April 25-26 - 2022/Indeed/Indeed-sound engineer.csv","../../Raw_CSV/April 27 - 2022/Indeed/Indeed-sound engineer.csv", "../../Raw_CSV/April 28 - 2022/Indeed/Indeed-sound engineer.csv","../../Raw_CSV/April 21-22 - 2022/Indeed/sound-engineer.csv"]),ignore_index=True)

# %%
#Describing the data
merge.describe()
# Out:
#                 Title Company SalaryOne SalaryTwo Location  \
# count             345     345       300       300      345
# unique            128      98        16        10       49
# top     Site Engineer   Dyson      None      None   Manila
# freq               13      24       273       285       67
#
#                                                   Summary Qualification  \
# count                                                 344           300
# unique                                                127           145
# top     There is emphasis on proactive monitoring, gov...            []
# freq                                                   12            20
#
#        Role&Responsibilities
# count                    300
# unique                   130
# top                       []
# freq                      55

# %%
#View Data's
merge
# Out:
#                                                  Title  \
# 0    ENVIRONMENTAL Engineers (New Graduate and Juni...
# 1     GEOTECHNICAL Engineers ( Junior to Senior Level)
# 2                                      Sound Engineers
# 3                                       Sound Engineer
# 4                                Motor Drives Engineer
# ..                                                 ...
# 340                                Staff Test Engineer
# 341                    Operations Center Engineer Lead
# 342                                newFlutter Engineer
# 343  newTechnical/ Cybersecurity Support Engineer L...
# 344                                      Site Engineer
#
#                                        Company  \
# 0                                 SP Solutions
# 1                                 SP Solutions
# 2    Polytechnic University of the Philippines
# 3                            Chupana Marketing
# 4                  Dyson Manufacturing Sdn Bhd
# ..                                         ...
# 340                           ON Semiconductor
# 341                     Joe Riley & Associates
# 342                      Peregrine Recruitment
# 343                                     Sophos
# 344                       Intecore Corporation
#
#                             SalaryOne SalaryTwo                      Location  \
# 0     PHP 25,000 - PHP 50,000 a month      None  Temporarily Remote in Manila
# 1    PHP 25,000 - PHP 100,000 a month      None  Temporarily Remote in Manila
# 2                                None      None                   Philippines
# 3     PHP 30,000 - PHP 40,000 a month      None              Remote in Manila
# 4                                None      None                   Philippines
# ..                                ...       ...                           ...
# 340                               NaN       NaN                       Carmona
# 341                               NaN       NaN                   Mandaluyong
# 342                               NaN       NaN              Remote in Manila
# 343                               NaN       NaN                        Makati
# 344                               NaN       NaN                   Quezon City
#
#                                                Summary  \
# 0    Sound technical understanding and knowledge of...
# 1    Sound technical understanding and knowledge of...
# 2                                                 None
# 3                      Test and improve sound quality.
# 4    Experience of managing a small team of engineers.
# ..                                                 ...
# 340  Perform qualification, test release, and produ...
# 341  Analyzes infrastructure capacity and performan...
# 342  Designing and building mobile and web applicat...
# 343  Ability to handle escalated calls while using ...
# 344  To be successful as a site engineer, you shoul...
#
#                                          Qualification  \
# 0    ['Sound technical understanding and knowledge ...
# 1    ['Sound technical understanding and knowledge ...
# 2                                                   []
# 3                   ['Work from home', '8 hour shift']
# 4    ['Working closely with the design lead, you wi...
# ..                                                 ...
# 340                                                NaN
# 341                                                NaN
# 342                                                NaN
# 343                                                NaN
# 344                                                NaN
#
#                                  Role&Responsibilities
# 0    ['SoilProbe Solutions, a company of Stratton P...
# 1    ['Geotechnical Engineer (Junior to Senior Leve...
# 2                                                   []
# 3    ['Job Description:', '- Create the soundtrack ...
# 4                                                   []
# ..                                                 ...
# 340                                                NaN
# 341                                                NaN
# 342                                                NaN
# 343                                                NaN
# 344                                                NaN
#
# [345 rows x 8 columns]

# %%
location = merge["Location"].value_counts()[0:10] # Location
salary = merge["SalaryOne"] + " " + merge["SalaryTwo"] # Salary
title = merge["Title"].value_counts()[0:10]

# %%
location.to_frame()
# Out:
#                               Location
# Manila                              67
# Makati                              42
# Philippines                         42
# Quezon City                         19
# Remote in Manila                    16
# Temporarily Remote in Manila        13
# National Capital Region             12
# Taguig                               8
# Pasig                                8
# Muntinlupa                           7

# %%
plt.bar(location.index, location.values,width=0.3)
plt.title("Indeed Sound Engineer Location")
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
title.to_frame()
# Out:
#                                                Title
# Site Engineer                                     13
# Systems Engineer                                  11
# Civil Site Engineer                                8
# Building Engineer                                  8
# Senior Process Engineer                            7
# Sound Engineer                                     7
# Repair and Maintenance Engineer                    7
# Structural Engineer                                6
# newProfessional Services Engineer                  6
# newApplication Engineer for Process Analytics      5

# %%
plt.barh(title.index, title.values)
plt.title("Indeed Sound Engineer")
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
company = merge["Company"].value_counts()[0:10]

# %%
company.to_frame()
# Out:
#                                        Company
# Dyson                                       24
# Mettler Toledo                              13
# Wells Fargo                                 12
# Peregrine Recruitment                       11
# Procter & Gamble                            10
# Sophos                                       9
# Black & Veatch                               9
# Ergo Contracts Philippines, Inc.             8
# Grundfos                                     8
# Newcore Industries International, Inc        8

# %%
plt.bar(company.index, company.values)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
replace = merge["Qualification"].str.replace("^\['|'\]$","")
# Out:
# /var/folders/tc/qdg72rpx523gjsqcr2vf_0c00000gn/T/ipykernel_3506/1200321832.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   replace = merge["Qualification"].str.replace("^\['|'\]$","")

# %%
for i in range(len(merge["Qualification"])):
    a_list = literal_eval(merge["Qualification"][i])
    for j in range(len(a_list)):
        #print(a_list[j])
# Out:
#   Input In [15]
#     #print(a_list[j])
#                      ^
# SyntaxError: incomplete input
