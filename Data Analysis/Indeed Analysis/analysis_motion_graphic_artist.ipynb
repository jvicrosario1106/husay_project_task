# %%
import matplotlib.pyplot as plt
import pandas as pd
from ast import literal_eval
import re

# %%
merge = pd.concat(map(pd.read_csv, ["../../Raw_CSV/April 25-26 - 2022/Indeed/Indeed-motion graphic artist.csv","../../Raw_CSV/April 27 - 2022/Indeed/Indeed-motion graphic artist.csv", "../../Raw_CSV/April 28 - 2022/Indeed/Indeed-motion-graphic-artist.csv","../../Raw_CSV/April 21-22 - 2022/Indeed/motion-graphic-artist.csv"]),ignore_index=True)

# %%
#Describing the data
merge.describe()
# Out:
#                     Title        Company SalaryOne SalaryTwo Location  \
# count                 226            226       181       181      226
# unique                 42             54         9         9       26
# top     Multimedia Artist  Bold Business      None      None   Manila
# freq                   36             12       171       156       46
#
#                                                   Summary Qualification  \
# count                                                 226           181
# unique                                                 50            56
# top     Research the latest trends in web designs and ...            []
# freq                                                   17            28
#
#        Role&Responsibilities
# count                    181
# unique                    45
# top                       []
# freq                      60

# %%
#View Data's
merge
# Out:
#                                       Title  \
# 0                     Senior Graphic Artist
# 1                         newGraphic Artist
# 2    Social Media Graphic and Motion Artist
# 3                         newGraphic Artist
# 4                         newGraphic Artist
# ..                                      ...
# 221       Graphic Designer (WORK FROM HOME)
# 222                        Technical Artist
# 223              UX Designer/Graphic Artist
# 224          Visual Development Artist - NA
# 225                       Senior Visualizer
#
#                                 Company                        SalaryOne  \
# 0       ONE OASIS PREMIER HOLDINGS CORP                             None
# 1                     Fisherfarms, Inc.                             None
# 2    Firstcom Solutions Technology Inc.                             None
# 3            One Outsource Direct Corp.  PHP 15,000 - PHP 20,000 a month
# 4               Cherenz Global Mfg. Inc                             None
# ..                                  ...                              ...
# 221                    Sprout Solutions                              NaN
# 222                             Ubisoft                              NaN
# 223                 Optimum Source Inc.                              NaN
# 224                Willis Towers Watson                              NaN
# 225                   GMA Network, Inc.                              NaN
#
#     SalaryTwo                     Location  \
# 0        None                        Pasay
# 1        None  Temporarily Remote in Pasig
# 2        None                       Makati
# 3        None                       Makati
# 4        None                       Manila
# ..        ...                          ...
# 221       NaN                       Remote
# 222       NaN              Santa Rosa City
# 223       NaN                        Pasig
# 224       NaN                       Manila
# 225       NaN                       Manila
#
#                                                Summary  \
# 0    Expert knowledge of Adobe Creative Software, E...
# 1    Create motion graphics, web designs, packaging...
# 2    Implement brand standards and produce static a...
# 3              Experience in HTML and motion graphics.
# 4    Can work with video, graphic, motion graphic c...
# ..                                                 ...
# 221  Experience with video production, motion graph...
# 222  Ensure that graphic bugs are fixed according t...
# 223  Experience with motion graphic design using Ad...
# 224  Graduate or attended any course related to cre...
# 225  A.) Graduate of BA Visual Communication, Multi...
#
#                                          Qualification  \
# 0    ['Design and produce marketing communications ...
# 1    ['Online Hiring Process', 'DTI and DOLE Interi...
# 2    ["\nWork with account executives who handle th...
# 3    ['We’re in the business of delivering innovati...
# 4    ['Actively solve design problems by being adep...
# ..                                                 ...
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
# 225                                                NaN
#
#                                  Role&Responsibilities
# 0    ['Job Summary: ', 'The Senior Graphic Artist i...
# 1    ['Have an ISDAmazing experience with Fisher Fa...
# 2    ['FirstCom Solutions is a one-stop go digital ...
# 3    ['About One Outsource Group (OOG)', 'Establish...
# 4                                                   []
# ..                                                 ...
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
# 225                                                NaN
#
# [226 rows x 8 columns]

# %%
location = merge["Location"].value_counts()[0:10] # Location
salary = merge["SalaryOne"] + " " + merge["SalaryTwo"] # Salary
title = merge["Title"].value_counts()[0:10]

# %%
location.to_frame()
# Out:
#                        Location
# Manila                       46
# Makati                       18
# Pasig                        15
# Taguig                       14
# Philippines                  13
# Santa Rosa City              12
# Remote in Pasig              12
# Remote in Makati             11
# Remote                       11
# Remote in Philippines         9

# %%
plt.bar(location.index, location.values,width=0.3)
plt.title("Indeed Motion Graphic Artist Location")
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
title.to_frame()
# Out:
#                                        Title
# Multimedia Artist                         36
# Motion Graphic Artist                     12
# newGraphic Artist                         12
# Technical Artist                          12
# Graphic Designer                          12
# Graphic Artist                             8
# Multimedia/Creatives Interns               8
# Senior Multimedia Artist                   7
# Motion Graphics Artist                     7
# Photographer/Videographer (Freelance)      7

# %%
plt.barh(title.index, title.values)
plt.title("Indeed Motion Graphic Artist")
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
company = merge["Company"].value_counts()[0:10]

# %%
company.to_frame()
# Out:
#                                     Company
# Bold Business                            12
# GMA Network, Inc.                        10
# University of Santo Tomas                 9
# Skillz Inc.                               9
# PurpleBug                                 8
# Leadya Services Inc.                      7
# Duckten Corporation - Eljan Sports        7
# Focus Global Inc.                         7
# i21 recruitment                           7
# Willis Towers Watson                      7

# %%
plt.bar(company.index, company.values)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
replace = merge["Qualification"].str.replace("^\['|'\]$","")
# Out:
# /var/folders/tc/qdg72rpx523gjsqcr2vf_0c00000gn/T/ipykernel_2432/1200321832.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   replace = merge["Qualification"].str.replace("^\['|'\]$","")

# %%
for i in range(len(merge["Qualification"])):
    a_list = literal_eval(merge["Qualification"][i])
    for j in range(len(a_list)):
        #print(a_list[j])
# Out:
#   Input In [28]
#     #print(a_list[j])
#                      ^
# SyntaxError: incomplete input
