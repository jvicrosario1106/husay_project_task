# %%
import matplotlib.pyplot as plt
import pandas as pd
from ast import literal_eval
import re

# %%
merge = pd.concat(map(pd.read_csv, ["../Raw_CSV/April 25-26 - 2022/Indeed/Indeed-multimedia artist.csv","../Raw_CSV/April 27 - 2022/Indeed/Indeed-multimedia artist.csv", "../Raw_CSV/April 28 - 2022/Indeed/Indeed-multimedia-artist.csv","../Raw_CSV/April 21-22 - 2022/Indeed/multimedia-artist.csv"]),ignore_index=True)

# %%
#Describing the data
merge.describe()
# Out:
#                     Title                         Company SalaryOne SalaryTwo  \
# count                 298                             298       268       268
# unique                 65                             127        21        29
# top     Multimedia Artist  iOPEX Technologies Philippines      None      None
# freq                   95                              16       235       207
#
#        Location                                            Summary  \
# count       298                                                298
# unique       44                                                127
# top      Makati  *Must have experience as a Graphic Artist or a...
# freq         60                                                 18
#
#        Qualification Role&Responsibilities
# count            268                   268
# unique           129                   122
# top               []                    []
# freq              21                    38

# %%
#View Data's
merge
# Out:
#                                     Title  \
# 0          Livestream - Multimedia Artist
# 1         Multimedia Artist (BGC, Taguig)
# 2             Multimedia Artist** URGENT!
# 3           Multimedia Artist (BGC Based)
# 4                       Multimedia Artist
# ..                                    ...
# 293  Graphic Artist - Head Office (Pasay)
# 294                     newGraphic Artist
# 295                     Multimedia Artist
# 296                     newGraphic Artist
# 297                     Multimedia Artist
#
#                                       Company  \
# 0                                      Shopee
# 1                    Monde Nissin Corporation
# 2                    Out of the Box Creatives
# 3                    Monde Nissin Corporation
# 4                                      Shopee
# ..                                        ...
# 293  Casamia Furniture Center Inc. (Our Home)
# 294                      Penscott Corporation
# 295                          Bueno Foundation
# 296                One Outsource Direct Corp.
# 297                          KMC Savills Inc.
#
#                            SalaryOne SalaryTwo     Location  \
# 0                               None      None       Taguig
# 1                               None      None       Taguig
# 2    PHP 20,000 - PHP 25,000 a month      None       Makati
# 3                               None      None  Philippines
# 4                               None      None       Manila
# ..                               ...       ...          ...
# 293                              NaN       NaN        Pasay
# 294                              NaN       NaN       Makati
# 295                              NaN       NaN       Makati
# 296                              NaN       NaN       Makati
# 297                              NaN       NaN       Taguig
#
#                                                Summary  \
# 0    Collaborate with cross-functional marketing te...
# 1    Candidate must possess at least a Bachelor's/C...
# 2    *Able to prepare rough drafts and present ideas*.
# 3    The position includes the entire process of vi...
# 4    Design templates for video assets and create m...
# ..                                                 ...
# 293  \*Graduate of Advertising, fine arts, Multimed...
# 294  Responsible in creating graphic designs for br...
# 295  Able to adapt on today's trend but still able ...
# 296  The Graphic Artist (GA)is responsible for over...
# 297  1 year experience in multimedia design and dig...
#
#                                          Qualification  \
# 0    ["Interpret business needs to develop concepts...
# 1    ["Interpret business needs to develop concepts...
# 2    ['Conceptualize designs and visual-based on re...
# 3                                                   []
# 4    ['Design templates for video assets and create...
# ..                                                 ...
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
#
#                                  Role&Responsibilities
# 0                                                   []
# 1                                                   []
# 2    ['Job Types: Full-time, Contract', 'Salary: Ph...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
#
# [298 rows x 8 columns]

# %%
location = merge["Location"].value_counts()[0:10] # Location
salary = merge["SalaryOne"] + " " + merge["SalaryTwo"] # Salary
title = merge["Title"].value_counts()[0:10]

# %%
location.to_frame()
# Out:
#                   Location
# Makati                  60
# Taguig                  32
# Quezon City             31
# Manila                  21
# Remote in Taguig        16
# Pasig                   15
# Remote in Pasig         15
# Philippines             15
# Remote in Manila        11
# Pasay                   10

# %%
plt.bar(location.index, location.values,width=0.3)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
title.to_frame()
# Out:
#                                            Title
# Multimedia Artist                             95
# newGraphic Artist                             37
# newMultimedia Artist                          19
# Graphic Artist                                13
# Junior Multimedia Artist                      11
# Technical Director | Multimedia Artist         7
# Graphic/Multimedia Artist l BGC, Taguig        7
# Creative Multimedia Artist                     5
# Multimedia Artist/Editor                       4
# Multimedia Assistant (Jr. Graphic Artist)      4

# %%
plt.bar(title.index, title.values,width=0.3,)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
company = merge["Company"].value_counts()[0:10]

# %%
company.to_frame()
# Out:
#                                             Company
# iOPEX Technologies Philippines                   16
# Shopee                                           14
# Asticom                                           7
# Penscott Corporation                              7
# Fil-Chi Media Productions Inc. (Chinoy TV)        7
# Bueno Foundation                                  6
# Winery.ph                                         5
# Monde Nissin Corporation                          5
# StorageMart Corporation                           5
# Universal Access and Systems Solutions            5

# %%
plt.bar(company.index, company.values)
plt.xticks(rotation=30,ha="right")
plt.show()

# %%
replace = merge["Qualification"].str.replace("^\['|'\]$","")
# Out:
# /var/folders/tc/qdg72rpx523gjsqcr2vf_0c00000gn/T/ipykernel_4068/1200321832.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   replace = merge["Qualification"].str.replace("^\['|'\]$","")

# %%
for i in range(len(merge["Qualification"])):
    a_list = literal_eval(merge["Qualification"][i])
    for j in range(len(a_list)):
        #print(a_list[j])
