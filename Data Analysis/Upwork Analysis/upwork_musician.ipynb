# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_path = [
   "../../Raw_CSV/April 25-26 - 2022/Upwork/Upwork_Musician.csv",
   "../../Raw_CSV/April 27 - 2022/Upwork/Upwork-Musician.csv",
    "../../Raw_CSV/April 28 - 2022/Upwork/Freelance Musician Jobs - Upwork.csv", 
]
merge = pd.concat(map(pd.read_csv,csv_path),ignore_index=True)
merge["Skill"]= merge["Skill"].str.replace("^\['|'\]$","")
merge
# Out:
# /var/folders/tc/qdg72rpx523gjsqcr2vf_0c00000gn/T/ipykernel_989/4227134558.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   merge["Skill"]= merge["Skill"].str.replace("^\['|'\]$","")
#                                                  Title  \
# 0              Seeking for Spotify/Music Growth Expert
# 1    I need you to create a music player that plays...
# 2    Graphic Designer Needed For Album Artwork + Re...
# 3    Expert Music Supervisor (and Music Library) Pr...
# 4             Logo/ Brand identity for musician needed
# ..                                                 ...
# 335  Video Editor needed for a music performance mi...
# 336                                 Multy Style Choreo
# 337               Need theme music for a startup brand
# 338  Piano Teacher for Online Piano Lessons - Fully...
# 339  Pianist for wedding 6/4/22 in Worcester Massac...
#
#                                            Description Location  \
# 0    Seeking for music growth expert on platforms l...     None
# 1    This is for a Squarespace site.  I write origi...     None
# 2    I'm looking for a designer who can create a nu...     None
# 3    Are you an experienced Music Promotion Expert?...     None
# 4    Must have experience in creating branded visua...     None
# ..                                                 ...      ...
# 335  I had a friend recently record a local artist ...      NaN
# 336  CREATE A CHOREOGRAPHY (BASED ON KPOP) WITH THI...      NaN
# 337  I need theme music for my brand\n\nCategory- o...      NaN
# 338  Lesson With You (“LWY”) is the leading US prov...      NaN
# 339  Looking for a pianist to play a few songs duri...      NaN
#
#                                                  Skill Est.Proj-Budget  \
# 0    Marketing Communications', 'Content Strategy',...            None
# 1                         Music', 'Electronic Keyboard            None
# 2                   Graphic Design', 'Cover Art Design            None
# 3           Media & Entertainment', 'Client Management            None
# 4    Website Asset', 'Brand Identity & Guidelines',...            None
# ..                                                 ...             ...
# 335                                                NaN             NaN
# 336                                                NaN             NaN
# 337                                                NaN             NaN
# 338                                                NaN             NaN
# 339                                                NaN             NaN
#
#                   Job Type Contractor Tier  \
# 0    Hourly: $10.00-$30.00    Intermediate
# 1    Hourly: $50.00-$63.00          Expert
# 2    Hourly: $35.00-$75.00          Expert
# 3    Hourly: $50.00-$75.00          Expert
# 4    Hourly: $15.00-$34.00    Intermediate
# ..                     ...             ...
# 335                    NaN             NaN
# 336                    NaN             NaN
# 337                    NaN             NaN
# 338                    NaN             NaN
# 339                    NaN             NaN
#
#                                       Duration  \
# 0    Less than 1 month, Hours to be determined
# 1        3 to 6 months, Hours to be determined
# 2         1 to 3 months, Less than 30 hrs/week
# 3         1 to 3 months, Less than 30 hrs/week
# 4         1 to 3 months, Less than 30 hrs/week
# ..                                         ...
# 335   Less than 1 month, Less than 30 hrs/week
# 336       1 to 3 months, Less than 30 hrs/week
# 337   Less than 1 month, Less than 30 hrs/week
# 338           More than 6 months, 30+ hrs/week
# 339   Less than 1 month, Less than 30 hrs/week
#
#                                              Title_URL               Job_type  \
# 0                                                  NaN                    NaN
# 1                                                  NaN                    NaN
# 2                                                  NaN                    NaN
# 3                                                  NaN                    NaN
# 4                                                  NaN                    NaN
# ..                                                 ...                    ...
# 335  https://www.upwork.com/job/Video-Editor-needed...  Hourly: $10.00-$25.00
# 336  https://www.upwork.com/job/Multy-Style-Choreo_...                 Hourly
# 337  https://www.upwork.com/job/Need-theme-music-fo...  Hourly: $15.00-$30.00
# 338  https://www.upwork.com/job/Piano-Teacher-for-O...  Hourly: $23.00-$33.00
# 339  https://www.upwork.com/job/Pianist-for-wedding...  Hourly: $30.00-$50.00
#
#     Contractor_tier           Skill_one            Skill_two  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
# ..              ...                 ...                  ...
# 335     Entry level       Video Editing      Final Cut Pro X
# 336    Intermediate             Dancing        Popping Dance
# 337    Intermediate  Experimental Music     Industrial Music
# 338    Intermediate               Piano  Electronic Keyboard
# 339    Intermediate               Piano                  NaN
#
#             skill_three     skill_four skill_five
# 0                   NaN            NaN        NaN
# 1                   NaN            NaN        NaN
# 2                   NaN            NaN        NaN
# 3                   NaN            NaN        NaN
# 4                   NaN            NaN        NaN
# ..                  ...            ...        ...
# 335  Adobe Premiere Pro  Final Cut Pro        NaN
# 336   Creative & Talent            NaN        NaN
# 337       Popular Music           Song        NaN
# 338                 NaN            NaN        NaN
# 339                 NaN            NaN        NaN
#
# [340 rows x 16 columns]

# %%
merge["Est.Proj-Budget"] = merge["Est.Proj-Budget"].str.strip()

# %%
filt = (merge["Est.Proj-Budget"] != "None") & (merge["Est.Proj-Budget"].notna())
filter_est = merge.loc[filt]
count_est = filter_est["Est.Proj-Budget"].value_counts()
plt.figure(figsize=(20, 5))
plt.bar(count_est.index, count_est.values)
plt.title("Musician")
plt.xticks(rotation=30, ha="right")
plt.show()

# %%
filt_first_tier = merge["Contractor_tier"].fillna("")
# frame_first_tier =  merge.loc[filt_first_tier,"Contractor_tier"]
filt_second_tier = merge["Contractor Tier"].fillna("")
# frame_second_tier = merge.loc[filt_second_tier,"Contractor Tier"]

merge["CT"] = filt_first_tier + filt_second_tier

# %%
merge["CT"] = merge["CT"].str.strip()

# %%
count_tier = merge["CT"].value_counts()
count_tier
# Out:
# Intermediate    177
# Expert           97
# Entry level      66
# Name: CT, dtype: int64

# %%
plt.barh(count_tier.index,count_tier.values)
plt.show()

# %%
merge["Combine Skills"] =   merge.Skill.fillna("") + " " + merge.Skill_one.fillna("") + "," + merge.Skill_two.fillna(",") + ", " + merge.skill_four.fillna(",") + ", " + merge.skill_three.fillna(",")

# %%
merge["Combine Skills"] = merge["Combine Skills"].str.replace("'", "")

# %%
merge["Combine Skills"] = merge["Combine Skills"].str.split(",")

# %%
skill_append = []
for i in range(len(merge["Combine Skills"])):
    count = merge["Combine Skills"][i]
    for j in range(len(count)):
        skill_append.append(count[j])

# %%
skill_without_space = []
filter_skill = list(filter(None, skill_append))
for i in filter_skill:
    if i != " ":
        skill_without_space.append(i)

# %%
skill_frame = pd.DataFrame(skill_without_space, columns={"Skill"})
count_skill = skill_frame["Skill"].value_counts()[0:10]
plt.figure(figsize=(10,5))
plt.title("Skills for Musician")
plt.barh(count_skill.index,count_skill.values)
plt.show()

# %%
merge["JT"] = merge["Job Type"].fillna("") + merge["Job_type"].fillna("")

# %%
count_jt = merge["JT"].value_counts()[0:10]
plt.figure(figsize=(10,5))
plt.bar(count_jt.index, count_jt.values)
plt.xticks(rotation="30",ha="right")
plt.show()

# %%
filt_loc = (merge["Duration"] != "None")
merge_duration = merge.loc[filt_loc,"Duration"]
count_duration = merge_duration.value_counts()
plt.figure(figsize=(15,5))
plt.bar(count_duration.index, count_duration.values)
plt.xticks(rotation="30",ha="right")
plt.show()

# %%
filt = (merge["CT"] == "Entry level")
count_entry_level = merge.loc[filt,"JT"].value_counts()[0:10]

plt.figure(figsize=(20,5))
plt.bar(count_entry_level.index, count_entry_level.values)
plt.title("Entry Level")
plt.xticks(rotation="30", ha="right")
plt.show()

# %%
filt = (merge["CT"] == "Intermediate")
count_entry_level = merge.loc[filt,"JT"].value_counts()[0:10]

plt.figure(figsize=(20,5))
plt.bar(count_entry_level.index, count_entry_level.values)
plt.title("Intermediate Level")
plt.xticks(rotation="30", ha="right")
plt.show()

# %%
filt = (merge["CT"] == "Expert")
count_entry_level = merge.loc[filt,"JT"].value_counts()[0:10]

plt.figure(figsize=(20,5))
plt.bar(count_entry_level.index, count_entry_level.values)
plt.title("Expert Level")
plt.xticks(rotation="30", ha="right")
plt.show()

# %%
count_job_title = merge["Title"].value_counts()[0:10]
plt.barh(count_job_title.index, count_job_title.values)
plt.title("Upwork Musician")
plt.xticks(rotation="30",ha="right")
plt.show()
