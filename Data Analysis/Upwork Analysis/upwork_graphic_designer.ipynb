# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_path = [
   "../../Raw_CSV/April 25-26 - 2022/Upwork/Upwork_Graphic_Designer.csv",
   "../../Raw_CSV/April 27 - 2022/Upwork/Upwork-Graphic-Designer.csv",
    "../../Raw_CSV/April 28 - 2022/Upwork/Freelance Graphic Designer Jobs - Upwork.csv", 
]
merge = pd.concat(map(pd.read_csv,csv_path),ignore_index=True)
merge["Skill"]= merge["Skill"].str.replace("^\['|'\]$","")
merge
# Out:
# /var/folders/tc/qdg72rpx523gjsqcr2vf_0c00000gn/T/ipykernel_3983/3982761815.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   merge["Skill"]= merge["Skill"].str.replace("^\['|'\]$","")
#                                                  Title  \
# 0                            Need UI designer on figma
# 1             Design a Book Cover for a Murder Mystery
# 2                          Experienced designer needed
# 3               Lightroom Photo Editor For a Long term
# 4      Graphic Designer To Design Youtube Cover Photos
# ..                                                 ...
# 485  Illustrator to design board game with minimal ...
# 486   Wedding album cover design psd with smart object
# 487  Brand Agency Seeking UX/UI Web Designer/Developer
# 488  Digital artist needed to make some vector desi...
# 489                   Beautiful infographic PDF design
#
#                                            Description Location  \
# 0    I need UI designer on figma any one interested...     None
# 1    I've finished my first novel and need a creati...     None
# 2    Urgent Experienced designers needed I'm lookin...     None
# 3    I Need someone to Edit Image, Color Correction...     None
# 4    Hello, We're looking for a graphic designer wh...     None
# ..                                                 ...      ...
# 485  We're looking for a playful artist to help us ...      NaN
# 486  Wedding album cover designer need\n1. Use 2/3 ...      NaN
# 487  LET'S MAKE SOME MAGIC!!\n\nImaj Design Studio ...      NaN
# 488  hi, I need someone experienced enough to conve...      NaN
# 489  Thrive offers the most scientifically robust h...      NaN
#
#                                                  Skill        Est.Proj-Budget  \
# 0                Web Design', 'Graphic Design', 'Figma  \n        $20\n
# 1    Graphic Design', 'Cover Art Design', 'Layout D...                   None
# 2    Graphic Design', 'Web Design', 'Logo Design', ...                   None
# 3    Adobe Photoshop Lightroom', 'Photo Color Corre...                   None
# 4    Graphic Design', 'Adobe Photoshop', 'Adobe Ill...                   None
# ..                                                 ...                    ...
# 485                                                NaN                    NaN
# 486                                                NaN                    NaN
# 487                                                NaN                    NaN
# 488                                                NaN                    NaN
# 489                                                NaN                    NaN
#
#                   Job Type Contractor Tier  \
# 0              Fixed-price          Expert
# 1    Hourly: $20.00-$45.00          Expert
# 2    Hourly: $15.00-$34.00    Intermediate
# 3     Hourly: $5.00-$20.00    Intermediate
# 4                   Hourly          Expert
# ..                     ...             ...
# 485                    NaN             NaN
# 486                    NaN             NaN
# 487                    NaN             NaN
# 488                    NaN             NaN
# 489                    NaN             NaN
#
#                                       Duration  \
# 0                                         None
# 1     Less than 1 month, Less than 30 hrs/week
# 2         1 to 3 months, Less than 30 hrs/week
# 3              Less than 1 month, 30+ hrs/week
# 4    Less than 1 month, Hours to be determined
# ..                                         ...
# 485       1 to 3 months, Less than 30 hrs/week
# 486                                        NaN
# 487  More than 6 months, Less than 30 hrs/week
# 488   Less than 1 month, Less than 30 hrs/week
# 489       1 to 3 months, Less than 30 hrs/week
#
#                                              Title_URL               Job_type  \
# 0                                                  NaN                    NaN
# 1                                                  NaN                    NaN
# 2                                                  NaN                    NaN
# 3                                                  NaN                    NaN
# 4                                                  NaN                    NaN
# ..                                                 ...                    ...
# 485  https://www.upwork.com/job/Illustrator-design-...                 Hourly
# 486  https://www.upwork.com/job/Wedding-album-cover...            Fixed-price
# 487  https://www.upwork.com/job/Brand-Agency-Seekin...  Hourly: $20.00-$50.00
# 488  https://www.upwork.com/job/Digital-artist-need...   Hourly: $5.00-$20.00
# 489  https://www.upwork.com/job/Beautiful-infograph...  Hourly: $15.00-$60.00
#
#     Contractor_tier       Skill_one         Skill_two       skill_three  \
# 0               NaN             NaN               NaN               NaN
# 1               NaN             NaN               NaN               NaN
# 2               NaN             NaN               NaN               NaN
# 3               NaN             NaN               NaN               NaN
# 4               NaN             NaN               NaN               NaN
# ..              ...             ...               ...               ...
# 485          Expert  Graphic Design  Character Design               NaN
# 486          Expert  Graphic Design  Cover Art Design      Print Design
# 487    Intermediate    Email Design        Web Design    Graphic Design
# 488          Expert  Graphic Design       Logo Design  Character Design
# 489    Intermediate    Print Design  Editorial Design    Graphic Design
#
#                     skill_four
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 485           Concept Artistry
# 486  Adobe Photoshop Lightroom
# 487               Landing Page
# 488               Print Design
# 489              Layout Design
#
# [490 rows x 15 columns]

# %%
merge["Est.Proj-Budget"] = merge["Est.Proj-Budget"].str.strip()

# %%
filt = (merge["Est.Proj-Budget"] != "None") & (merge["Est.Proj-Budget"].notna())
filter_est = merge.loc[filt]
count_est = filter_est["Est.Proj-Budget"].value_counts()
plt.figure(figsize=(20, 5))
plt.bar(count_est.index, count_est.values)
plt.xticks(rotation=30, ha="right")
plt.show()

# %%
filt_first_tier = merge["Contractor_tier"].fillna("")
# frame_first_tier =  merge.loc[filt_first_tier,"Contractor_tier"]
filt_second_tier = merge["Contractor Tier"].fillna("")
# frame_second_tier = merge.loc[filt_second_tier,"Contractor Tier"]

merge["CT"] = filt_first_tier + filt_second_tier

# %%
merge["CT"] = merge["CT"].str.strip()

# %%
count_tier = merge["CT"].value_counts()
count_tier
# Out:
# Intermediate    249
# Expert          132
# Entry level     109
# Name: CT, dtype: int64

# %%
plt.barh(count_tier.index,count_tier.values)
plt.show()

# %%
merge["Combine Skills"] =   merge.Skill.fillna("") + " " + merge.Skill_one.fillna("") + "," + merge.Skill_two.fillna(",") + ", " + merge.skill_four.fillna(",") + ", " + merge.skill_three.fillna(",")

# %%
merge["Combine Skills"] = merge["Combine Skills"].str.replace("'", "")

# %%
merge["Combine Skills"] = merge["Combine Skills"].str.split(",")

# %%
skill_append = []
for i in range(len(merge["Combine Skills"])):
    count = merge["Combine Skills"][i]
    for j in range(len(count)):
        skill_append.append(count[j])

# %%
skill_without_space = []
filter_skill = list(filter(None, skill_append))
for i in filter_skill:
    if i != " ":
        skill_without_space.append(i)

# %%
skill_frame = pd.DataFrame(skill_without_space, columns={"Skill"})
count_skill = skill_frame["Skill"].value_counts()[0:10]
plt.figure(figsize=(10,5))
plt.barh(count_skill.index,count_skill.values)
plt.show()

# %%
merge["JT"] = merge["Job Type"].fillna("") + merge["Job_type"].fillna("")

# %%
count_jt = merge["JT"].value_counts()[0:10]
plt.figure(figsize=(10,5))
plt.bar(count_jt.index, count_jt.values)
plt.xticks(rotation="30",ha="right")
plt.show()

# %%
filt_loc = (merge["Duration"] != "None")
merge_duration = merge.loc[filt_loc,"Duration"]
count_duration = merge_duration.value_counts()
plt.figure(figsize=(15,5))
plt.bar(count_duration.index, count_duration.values)
plt.xticks(rotation="30",ha="right")
plt.show()

# %%
filt = (merge["CT"] == "Entry level")
count_entry_level = merge.loc[filt,"JT"].value_counts()[0:10]

plt.figure(figsize=(20,5))
plt.bar(count_entry_level.index, count_entry_level.values)
plt.title("Entry Level")
plt.xticks(rotation="30", ha="right")
plt.show()

# %%
filt = (merge["CT"] == "Intermediate")
count_entry_level = merge.loc[filt,"JT"].value_counts()[0:10]

plt.figure(figsize=(20,5))
plt.bar(count_entry_level.index, count_entry_level.values)
plt.title("Intermediate Level")
plt.xticks(rotation="30", ha="right")
plt.show()

# %%
filt = (merge["CT"] == "Expert")
count_entry_level = merge.loc[filt,"JT"].value_counts()[0:10]

plt.figure(figsize=(20,5))
plt.bar(count_entry_level.index, count_entry_level.values)
plt.title("Expert Level")
plt.xticks(rotation="30", ha="right")
plt.show()

# %%
count_job_title = merge["Title"].value_counts()[0:10]
plt.barh(count_job_title.index, count_job_title.values)
plt.title("Upwork Graphic Designer")
plt.xticks(rotation="30",ha="right")
plt.show()
